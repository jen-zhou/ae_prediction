# %%
import pandas as pd
import os as os
import json as json
import ast
import pickle
import openpyxl

# %%
patient_safety_df = pd.read_pickle('../fda_data/parsed_data/patient_safety_2015.pk')

# %%
patient_safety_df

# %%
col_names = ['MedDRA Code', 'MedDRA LLT', 'SNOMED CT CODE', 'SNOMED CT FSN', 'CANCER GROUP'] 

# mapping of MedDRA Codes to Cancer Groups
meddra_mapping_df = pd.read_excel(
    '../fda_data/MedDRA_Mapping_with_Cancer_Group_Breast_Identified.xlsx',
    engine='openpyxl',
    names = col_names
)

# %%
meddra_mapping_df['CANCER GROUP'].unique()
# Out:
# array(['Cancer Group', nan, 'Leukemia', 'Other Cancer', 'Stomach', 'Lung',
#        'Lymphoma', 'Breast', 'Colorectal', 'Melanoma', 'Pancreatic'],
#       dtype=object)

# %%
# Step 1: Explode the list of string indications
exploded_df = patient_safety_df.explode('indications')

# Step 2: Convert indications to int for matching
meddra_mapping_df['MedDRA Code'] = meddra_mapping_df['MedDRA Code'].astype(str)

# Step 3: Merge with meddra_mapping_df on the MedDRA code
merged_df = exploded_df.merge(
    meddra_mapping_df,
    left_on='indications',
    right_on='MedDRA Code',
    how='left'
)

# %%
merged_df['CANCER GROUP'].unique()
# Out:
# array([nan, 'Other Cancer', 'Breast', 'Leukemia', 'Melanoma', 'Lymphoma',
#        'Colorectal', 'Lung', 'Pancreatic', 'Stomach'], dtype=object)

# %%
# Step 4: Group by original index and get first non-null cancer type
cancer_type_map = merged_df.groupby(merged_df.index)['CANCER GROUP'].agg(lambda x: next((i for i in x if pd.notna(i)), None))

# Step 5: Add cancer type to original patient_safety_df
patient_safety_df['CANCER GROUP'] = patient_safety_df.index.map(cancer_type_map)

# %%
patient_safety_df['CANCER GROUP'].unique()
# Out:
# array([None, 'Other Cancer', 'Breast', 'Leukemia', 'Melanoma', 'Lymphoma',
#        'Colorectal', 'Lung', 'Pancreatic', 'Stomach'], dtype=object)

# %%
import matplotlib.pyplot as plt
cancer_counts = patient_safety_df['CANCER GROUP'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(cancer_counts, labels=cancer_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Cancer Types')
plt.axis('equal')  # Ensures the pie chart is a circle
plt.show()

# %%
meddra_mapping_df['CANCER GROUP'].unique()
# Out:
# array(['Cancer Group', nan, 'Leukemia', 'Other Cancer', 'Stomach', 'Lung',
#        'Lymphoma', 'Breast', 'Colorectal', 'Melanoma', 'Pancreatic'],
#       dtype=object)

# %%
breast_cancer_codes = meddra_mapping_df[meddra_mapping_df['CANCER GROUP'] == 'Breast']['MedDRA Code'].unique()

# %%
breast_cancer_codes = [str(code) for code in breast_cancer_codes]

# %%
meddra_mapping_df[meddra_mapping_df['CANCER GROUP'] == 'Breast']
# Out:
#      MedDRA Code                                        MedDRA LLT  \
# 680     10006173                             Breast adenocarcinoma
# 681     10006187                                     Breast cancer
# 682     10006188                          Breast cancer female NOS
# 683     10006190                        Breast cancer invasive NOS
# 684     10006192                                 Breast cancer NOS
# 685     10006198                           Breast cancer recurrent
# 686     10006200                            Breast cancer stage II
# 687     10006201                           Breast cancer stage III
# 688     10006202                            Breast cancer stage IV
# 692     10006235                 Breast ductal cancer infiltrating
# 699     10006283                  Breast neoplasm malignant female
# 706     10006315                            Breast tumor malignant
# 707     10006317                           Breast tumour malignant
# 789     10007305                                  Carcinoma breast
# 2349    10021944                 Infiltrating ductal breast cancer
# 2432    10022882                     Invasive ductal breast cancer
# 2728    10025541                         Malignant breast neoplasm
# 2741    10025920               Malignant neoplasm of female breast
# 2742    10025921  Malignant neoplasm of female breast, unspecified
# 2833    10027475                          Metastatic breast cancer
# 5201    10053566                           Breast ductal carcinoma
# 5328    10055113                          Breast cancer metastatic
# 5484    10057654                              Breast cancer female
# 6145    10065430                       HER2 positive breast cancer
# 6557    10072737                            Advanced breast cancer
# 6579    10073095                  Invasive ductal breast carcinoma
#
#      SNOMED CT CODE                                      SNOMED CT FSN  \
# 680       865954003                Adenocarcinoma of breast (disorder)
# 681       254837009            Malignant neoplasm of breast (disorder)
# 682       372064008     Malignant neoplasm of female breast (disorder)
# 683       713609000            Invasive carcinoma of breast (disorder)
# 684       254837009            Malignant neoplasm of breast (disorder)
# 685       314955001  Local recurrence of malignant tumor of breast ...
# 686       372137005    Primary malignant neoplasm of breast (disorder)
# 687       372137005    Primary malignant neoplasm of breast (disorder)
# 688       372137005    Primary malignant neoplasm of breast (disorder)
# 692       408643008   Infiltrating duct carcinoma of breast (disorder)
# 699       372064008     Malignant neoplasm of female breast (disorder)
# 706       254837009            Malignant neoplasm of breast (disorder)
# 707       254837009            Malignant neoplasm of breast (disorder)
# 789       254838004                     Carcinoma of breast (disorder)
# 2349      408643008   Infiltrating duct carcinoma of breast (disorder)
# 2432      408643008   Infiltrating duct carcinoma of breast (disorder)
# 2728      254837009            Malignant neoplasm of breast (disorder)
# 2741      372064008     Malignant neoplasm of female breast (disorder)
# 2742      372064008     Malignant neoplasm of female breast (disorder)
# 2833      372137005    Primary malignant neoplasm of breast (disorder)
# 5201      408643008   Infiltrating duct carcinoma of breast (disorder)
# 5328      372137005    Primary malignant neoplasm of breast (disorder)
# 5484      372064008     Malignant neoplasm of female breast (disorder)
# 6145      427685000  Human epidermal growth factor 2 positive carci...
# 6557      254837009            Malignant neoplasm of breast (disorder)
# 6579      408643008   Infiltrating duct carcinoma of breast (disorder)
#
#      CANCER GROUP
# 680        Breast
# 681        Breast
# 682        Breast
# 683        Breast
# 684        Breast
# 685        Breast
# 686        Breast
# 687        Breast
# 688        Breast
# 692        Breast
# 699        Breast
# 706        Breast
# 707        Breast
# 789        Breast
# 2349       Breast
# 2432       Breast
# 2728       Breast
# 2741       Breast
# 2742       Breast
# 2833       Breast
# 5201       Breast
# 5328       Breast
# 5484       Breast
# 6145       Breast
# 6557       Breast
# 6579       Breast

# %%
breast_cancer_df = patient_safety_df[patient_safety_df['CANCER GROUP']=='Breast']

# %%
patient_safety_df['CANCER GROUP'].unique()
# Out:
# array([None, 'Other Cancer', 'Breast', 'Leukemia', 'Melanoma', 'Lymphoma',
#        'Colorectal', 'Lung', 'Pancreatic', 'Stomach'], dtype=object)

# %%
for el in breast_cancer_df['SE']:
    if len(el) > 0:
        print(el)
# Out:
# ['10067585']
# ['10011077']
# ['10000891']
# ['10011078', '10028596']
# ['10008190', '10011078']
# ['10028596']
# ['10028596']
# ['10028596']
# ['10042434', '10051592']
# ['10006279', '10044034']
# ['10016288', '10031264', '10061188']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10011078']
# ['10034839']
# ['10012735', '10028813', '10037660', '10060769', '10073069']
# ['10008469', '10013709', '10043417', '10069327']
# ['10007559', '10037423', '10061024']
# ['10002424', '10015150', '10046735']
# ['10002034', '10011224', '10020578', '10020903', '10037087', '10047942', '10054889']
# ['10002974', '10006093', '10006475', '10028810', '10033318']
# ['10003553', '10004446', '10006298', '10007695', '10011878', '10012378', '10023003', '10027457', '10027459', '10029148', '10033609', '10039722', '10040979', '10041660', '10046571', '10067434', '10068067']
# ['10054112', '10076308']
# ['10010264', '10013709', '10016322', '10033371', '10039073']
# ['10013654', '10022524', '10050012']
# ['10061334']
# ['10011224', '10022061', '10022093', '10052251', '10053425']
# ['10027452']
# ['10061169']
# ['10013968', '10037377']
# ['10040829']
# ['10013573', '10016173', '10049848', '10063559']
# ['10000059', '10000496', '10027951', '10047700', '10047895']
# ['10003010']
# ['10001497', '10013573', '10013754', '10022437', '10022998', '10027951', '10028813', '10029412', '10033775', '10040984', '10047340', '10053762']
# ['10003119', '10070863']
# ['10007515', '10009192', '10010071', '10019663', '10019837', '10020575', '10020660', '10022773', '10038435', '10038695', '10052593', '10060933', '10061105']
# ['10002424', '10013573', '10019075']
# ['10022061', '10022067', '10022086', '10022094', '10053425', '10066083']
# ['10033295']
# ['10013781', '10043414']
# ['10013709', '10073513']
# ['10013709']
# ['10048737']
# ['10053483', '10054997']
# ['10013709', '10013709', '10064366']
# ['10002967']
# ['10043920']
# ['10003549', '10016256', '10061275']
# ['10020765', '10033425', '10043607']
# ['10010264']
# ['10070531']
# ['10013709']
# ['10000381']
# ['10048393']
# ['10003988', '10008469', '10008531', '10016825', '10019194', '10020751', '10028813', '10034568', '10051792']
# ['10013700']
# ['10019708']
# ['10012174', '10063743']
# ['10013709', '10076308']
# ['10008118', '10029350', '10059109']
# ['10012735', '10013946', '10018386', '10019211', '10028813', '10033371']
# ['10037377', '10043607']
# ['10022086']
# ['10005555', '10005557', '10010264', '10022067', '10022086', '10039447', '10047895', '10047899']
# ['10013710', '10038678']
# ['10013709']
# ['10003549']
# ['10011906', '10013654']
# ['10011906', '10013654']
# ['10065645']
# ['10016173', '10061225', '10061363']
# ['10011906']
# ['10025482', '10027599', '10048393']
# ['10017577', '10019211']
# ['10033775']
# ['10049848']
# ['10016825', '10039218']
# ['10017918', '10021518']
# ['10031282']
# ['10013786', '10054786']
# ['10000087', '10001760', '10005956', '10019303', '10020937', '10040984', '10047895', '10061428', '10062189']
# ['10018884', '10055847']
# ['10021789']
# ['10046901', '10056530']
# ['10002034']
# ['10006451']
# ['10046735']
# ['10037153', '10055798']
# ['10003239', '10006451', '10013709', '10013968', '10021789', '10028334', '10028391']
# ['10037660']
# ['10033775']
# ['10000081', '10000087']
# ['10057852']
# ['10039073']
# ['10004791', '10012601', '10060795']
# ['10061818']
# ['10042609']
# ['10035226']
# ['10023353', '10043220']
# ['10039906', '10042609']
# ['10013709', '10049084']
# ['10016322', '10025482', '10028810', '10062355']
# ['10028596', '10050528', '10051076']
# ['10033609']
# ['10015958', '10022437', '10034721', '10040753']
# ['10001760', '10012735', '10021688', '10028810']
# ['10013709']
# ['10002034', '10053483']
# ['10039906']
# ['10051620', '10061603']
# ['10005557']
# ['10018985']
# ['10013573', '10025482', '10047340', '10047895', '10049564']
# ['10029354', '10043554', '10047942', '10054889']
# ['10029148']
# ['10016803', '10040070', '10046571']
# ['10013709', '10061819', '10076309']
# ['10037660', '10046306']
# ['10003239', '10037660', '10054106']
# ['10022086', '10023424']
# ['10013709']
# ['10022061', '10022093', '10053425']
# ['10022061', '10022093']
# ['10037660', '10043521', '10068319']
# ['10016256', '10019211']
# ['10022052']
# ['10010144', '10036000']
# ['10001742', '10013968', '10043528']
# ['10011906', '10024855']
# ['10068319']
# ['10036790']
# ['10030124']
# ['10016173', '10022052', '10022086', '10024453']
# ['10040753']
# ['10046735']
# ['10000081', '10003988', '10016256', '10022086', '10022086']
# ['10003239', '10019974', '10046735']
# ['10014011', '10028810']
# ['10028334', '10028347']
# ['10016256', '10061428']
# ['10018290']
# ['10013709', '10037844', '10046571']
# ['10003553', '10003988', '10006451', '10008479', '10011224', '10036790', '10039101', '10047700', '10051572', '10061148']
# ['10002855', '10016322', '10021519', '10028810', '10038683', '10040882']
# ['10011224', '10020751', '10041232']
# ['10022052', '10022086']
# ['10016256', '10019211', '10022081', '10022107', '10022112', '10025482', '10028836', '10043521', '10052251', '10053425']
# ['10022086', '10064366']
# ['10016946', '10071404']
# ['10022086']
# ['10022094', '10022107', '10037153']
# ['10013709']
# ['10011906']
# ['10000087', '10056812']
# ['10003549', '10005186', '10007739', '10010305', '10016256', '10020765', '10022004', '10025482', '10034719', '10037855']
# ['10033615']
# ['10000087', '10012174', '10012735', '10013968', '10016256', '10022000', '10028813', '10039101', '10041232']
# ['10013709']
# ['10003988', '10013709', '10016256', '10017533', '10037844', '10061623', '10064198']
# ['10003549', '10012735', '10062355']
# ['10042128', '10068319']
# ['10008190']
# ['10011224', '10028164', '10062244']
# ['10037884']
# ['10016173', '10020100']
# ['10000081', '10010774', '10029410', '10042128', '10046571']
# ['10022004']
# ['10008605', '10013442', '10037377']
# ['10000081', '10012735', '10025482', '10028411', '10033371']
# ['10012735', '10013700', '10013968', '10016807', '10017918', '10021097', '10028813', '10047700']
# ['10008190', '10042772', '10059245']
# ['10011906']
# ['10013968', '10016322', '10021097', '10021630', '10022000', '10046571', '10059108']
# ['10013573', '10021036', '10021097']
# ['10028813', '10060933']
# ['10012378']
# ['10018498', '10025482', '10060950']
# ['10022086']
# ['10016256', '10016326', '10023469']
# ['10013709']
# ['10020751']
# ['10011906']
# ['10050031', '10062080']
# ['10067482', '10069327']
# ['10022437', '10028810']
# ['10011831', '10020431', '10060931', '10061471', '10073755']
# ['10061758']
# ['10010264']
# ['10023003', '10060800']
# ['10000081', '10016256', '10019211', '10027327', '10030295', '10046782', '10046798', '10054196', '10060800']
# ['10034263']
# ['10012378', '10013709', '10034263']
# ['10013968', '10015090', '10016173', '10016275', '10019196', '10019211', '10029216', '10033557']
# ['10028810', '10053762']
# ['10013709', '10027175', '10074902']
# ['10011906']
# ['10012174', '10069339']
# ['10000125', '10013709', '10022116']
# ['10024855', '10027175', '10039203']
# ['10028411', '10066371']
# ['10037844']
# ['10017822', '10049438']
# ['10033295']
# ['10011224', '10013968', '10058467', '10069326']
# ['10017577', '10022095', '10023232', '10066901']
# ['10059242']
# ['10016256', '10022086']
# ['10041232', '10043521', '10068319']
# ['10031252', '10061257']
# ['10051267']
# ['10011224', '10013990', '10036018', '10053123']
# ['10035628', '10054112']
# ['10013654']
# ['10000060', '10001347', '10001760', '10009208', '10012174', '10012708', '10013786', '10015090', '10016256', '10016256', '10016807', '10017533', '10017758', '10017853', '10018286', '10018292', '10019037', '10019708', '10020028', '10020772', '10020772', '10021111', '10024670', '10024690', '10028289', '10033307', '10033317', '10033425', '10037660', '10038153', '10040984', '10043709', '10044038', '10047626', '10047899', '10058097', '10060795', '10061210', '10061318', '10061403', '10061876', '10067585', '10068954', '10072419']
# ['10013654']
# ['10007617', '10010144']
# ['10011906']
# ['10021789']
# ['10006451']
# ['10005084', '10033371']
# ['10033425']
# ['10020910', '10022841', '10036590', '10071404']
# ['10049438']
# ['10028411', '10029410']
# ['10010144', '10042458']
# ['10002424', '10037087', '10056998', '10061877']
# ['10012174']
# ['10016326']
# ['10006784', '10010264', '10015150', '10015993']
# ['10012735', '10028411']
# ['10005557']
# ['10012441', '10037087']
# ['10005003']
# ['10005003']
# ['10005003']
# ['10011878', '10018830', '10028813', '10043882', '10047340']
# ['10005003']
# ['10046735']
# ['10020751', '10037844', '10046735']
# ['10012735', '10017944', '10069226']
# ['10002855', '10013573', '10022437', '10033664', '10057668']
# ['10013573', '10047609', '10051118']
# ['10016256', '10025482', '10042772']
# ['10067268']
# ['10000087', '10008479', '10011906', '10053762']
# ['10001760', '10002034', '10011906', '10016256', '10016322', '10019211', '10028347', '10033425', '10044565', '10047249']
# ['10011906', '10053762']
# ['10007617', '10028596']
# ['10028596']
# ['10007559', '10049768']
# ['10052086']
# ['10008190', '10049418']
# ['10002388']
# ['10011077', '10011078']
# ['10028596']
# ['10028600']
# ['10028596']
# ['10003549', '10012735', '10019303', '10025482']
# ['10002034', '10003549', '10005619']
# ['10005557', '10005630', '10008479', '10013968', '10014943', '10016588', '10016750', '10023215', '10025256', '10027878', '10029366', '10035598', '10037016', '10039073', '10040752', '10049438', '10052464', '10059570']
# ['10000081', '10002855', '10012374', '10012378', '10013709', '10016275', '10021097', '10022116', '10028813', '10034263', '10046810', '10048407', '10049119', '10049438', '10053683', '10061178', '10061245', '10067476', '10069868', '10074497', '10075192']
# ['10013709', '10041591']
# ['10033609']
# ['10025031']
# ['10006811']
# ['10000060', '10013968', '10025482', '10028596', '10040477', '10050584', '10053762', '10067476', '10074903']
# ['10011906']
# ['10007559']
# ['10011077', '10051093', '10054047', '10061758', '10062202']
# ['10007953', '10025310', '10051398']
# ['10007554', '10022972']
# ['10061520', '10069327']
# ['10047924', '10069327']
# ['10002855', '10013968', '10033295', '10033664']
# ['10037377']
# ['10036596']
# ['10001497', '10011831', '10014581', '10019063', '10020642', '10041466']
# ['10012434']
# ['10013781', '10013968', '10029410', '10043963']
# ['10011906']
# ['10008111']
# ['10028810']
# ['10013709']
# ['10020751', '10042682']
# ['10028813', '10033371', '10046571', '10047700']
# ['10016256', '10022079', '10022086']
# ['10011224', '10013952', '10016256', '10022086', '10022086', '10028810', '10039101', '10041232', '10058920', '10061224', '10064355']
# ['10003239', '10003549', '10003553', '10003988', '10012110', '10012735', '10013968', '10016275', '10017367', '10018092', '10019211', '10022086', '10022086', '10022437', '10030124', '10033307', '10042209']
# ['10042609']
# ['10022000']
# ['10037153']
# ['10016936', '10037087', '10048629', '10053692']
# ['10038389']
# ['10028813']
# ['10061304']
# ['10043515']
# ['10013573', '10022061', '10022086', '10028813', '10064355', '10069217']
# ['10010305', '10017367', '10019063', '10061422']
# ['10003239']
# ['10061623']
# ['10011906', '10053762']
# ['10022004', '10022086', '10022095', '10047895', '10053395', '10061857', '10070964']
# ['10022067', '10022067', '10022086', '10073753']
# ['10003239', '10033371']
# ['10069868']
# ['10022086', '10064355']
# ['10003239', '10011781', '10013709', '10054236']
# ['10002855', '10033775']
# ['10022067', '10022086']
# ['10060795']
# ['10022067']
# ['10037660']
# ['10013709']
# ['10067482', '10069327']
# ['10027514']
# ['10010305', '10013709', '10016825', '10019303', '10041552', '10044565', '10050296']
# ['10010774', '10018836', '10027864', '10039117', '10040831', '10042128', '10047899']
# ['10017413', '10037844', '10047942', '10061428']
# ['10030995', '10037087', '10037844']
# ['10016256', '10016326']
# ['10017413']
# ['10016256', '10017885', '10040882']
# ['10028334', '10038435']
# ['10024774', '10061218']
# ['10003549', '10012174', '10012735']
# ['10003549', '10006784', '10008531', '10012735', '10013952', '10013968', '10015946', '10015958', '10016322', '10016334', '10020642', '10022086', '10027374', '10033371', '10033775', '10041466', '10047513', '10050584', '10051077']
# ['10043414']
# ['10015150', '10019211', '10028813', '10033775', '10037844']
# ['10038435', '10067671']
# ['10056812']
# ['10006451']
# ['10057362']
# ['10007636', '10040047']
# ['10033425']
# ['10064882']
# ['10005750', '10010774', '10013538', '10047700']
# ['10028245', '10061422']
# ['10022061', '10022093']
# ['10011906', '10047943']
# ['10028810', '10037153']
# ['10005734', '10012174', '10019303', '10020642', '10049428', '10059895']
# ['10003239', '10037162', '10048959', '10060795']
# ['10006198', '10019211']
# ['10067585']
# ['10034829']
# ['10010144', '10073302']
# ['10010144', '10073302']
# ['10011906', '10037469', '10045555', '10048962', '10058974', '10070863']
# ['10012735', '10021519', '10028694', '10028813', '10029410', '10031009', '10047895', '10048886', '10061428', '10066995']
# ['10011906']
# ['10020100', '10065154']
# ['10065019']
# ['10001540']
# ['10053762']
# ['10033371', '10061218']
# ['10061920']
# ['10008629']
# ['10054112']
# ['10037844']
# ['10011906']
# ['10047531']
# ['10007559']
# ['10007554', '10013573', '10020642']
# ['10019211', '10028813']
# ['10037844']
# ['10017940']
# ['10005952', '10058046']
# ['10005724', '10005750', '10013916', '10022116', '10039394', '10042674', '10042682', '10048959', '10053692']
# ['10009887']
# ['10009126', '10021789', '10035664', '10037377', '10051055']
# ['10064774']
# ['10044008']
# ['10038435']
# ['10018276', '10065612']
# ['10013709', '10016322', '10023232']
# ['10000059', '10013709', '10040844']
# ['10025482', '10042464']
# ['10007572']
# ['10016256', '10020772', '10025482']
# ['10035598', '10061818', '10067946']
# ['10011906']
# ['10028813', '10047700', '10072268']
# ['10047513', '10047531', '10047654', '10047663']
# ['10010144', '10013654', '10070863']
# ['10016454', '10039117', '10039579', '10042212', '10047473', '10075049']
# ['10000381', '10029366', '10065553']
# ['10011906', '10053762']
# ['10010280', '10015543', '10033081', '10035009', '10045210', '10071404']
# ['10008590', '10013774', '10013781', '10013950', '10020751', '10022000', '10025482', '10047899', '10052140']
# ['10008958', '10029354', '10029366', '10029366', '10029366', '10029366', '10029366', '10035528', '10035528', '10035528', '10035528', '10047942', '10047942', '10047942']
# ['10069339']
# ['10033128']
# ['10019273', '10037451', '10071404']
# ['10002855', '10012378', '10016256', '10040477', '10049119', '10057668', '10061461']
# ['10037660', '10048669', '10049438', '10051398', '10062631']
# ['10002948', '10003549', '10013887', '10013916', '10039906', '10048393', '10048592', '10050256']
# ['10002034', '10013442', '10017955']
# ['10013700']
# ['10000060', '10008611', '10012735', '10013050', '10013786', '10016256', '10016766', '10017944', '10019211', '10020765', '10028334', '10040844', '10054193', '10057146']
# ['10037549', '10061818', '10067946']
# ['10008417', '10013774', '10013941', '10046910', '10048222']
# ['10002388', '10022972']
# ['10028596']
# ['10011077']
# ['10028596']
# ['10002388', '10067740']
# ['10002383', '10028596']
# ['10007559', '10008190', '10028596']
# ['10008190', '10011078', '10028596']
# ['10028596']
# ['10028596']
# ['10028596']
# ['10003210', '10007649', '10028596']
# ['10003211', '10028596']
# ['10028596']
# ['10028596']
# ['10018985']
# ['10028596']
# ['10028596']
# ['10008034']
# ['10008190']
# ['10002388', '10007559', '10011078', '10028596']
# ['10052086']
# ['10000891', '10052086']
# ['10007559', '10028596']
# ['10008190']
# ['10028596']
# ['10028596']
# ['10000891']
# ['10028596']
# ['10028596']
# ['10000891']
# ['10028596']
# ['10028596', '10049418']
# ['10028596']
# ['10008190']
# ['10028596']
# ['10028596']
# ['10028596']
# ['10000891']
# ['10007554']
# ['10002895', '10007610', '10007617', '10013722', '10034476']
# ['10000084', '10061178', '10064684']
# ['10008190']
# ['10067740']
# ['10008479', '10028596']
# ['10028596']
# ['10028600']
# ['10007559', '10028596']
# ['10028596']
# ['10028596']
# ['10011078', '10028596']
# ['10003658', '10007559', '10061532']
# ['10000087', '10001551', '10003481', '10060795']
# ['10028596']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10003210', '10007559']
# ['10007559']
# ['10007559']
# ['10061024']
# ['10007559']
# ['10007559']
# ['10016219', '10057840', '10069339']
# ['10061024']
# ['10007559']
# ['10003549', '10012378', '10046571', '10060933']
# ['10011906', '10013709', '10018884', '10021425', '10025482', '10026865', '10033359', '10035543']
# ['10000081', '10013968', '10019303', '10033557', '10035664', '10047895', '10056342', '10060800']
# ['10007559']
# ['10011078']
# ['10007559', '10028600']
# ['10007559']
# ['10020923', '10033371', '10047571', '10047650']
# ['10003285', '10013990', '10018867', '10022004', '10060800', '10061024', '10061917', '10064863']
# ['10013654']
# ['10013654']
# ['10012174', '10012373', '10014415', '10018875', '10023676', '10065718', '10069339']
# ['10022000']
# ['10013573']
# ['10010947', '10041466']
# ['10003239', '10028411', '10064658', '10075995', '10076309']
# ['10005557']
# ['10044755']
# ['10007739']
# ['10063782', '10073412']
# ['10012578']
# ['10029155']
# ['10003988', '10008479']
# ['10035718']
# ['10055798']
# ['10012378', '10021928', '10022116', '10033371', '10049119', '10061178', '10064684', '10069853', '10069868', '10074498']
# ['10005159', '10037087', '10065166']
# ['10074300']
# ['10019974']
# ['10053155']
# ['10022095', '10057362']
# ['10016029']
# ['10010144']
# ['10019909', '10028334']
# ['10011906']
# ['10011906']
# ['10062070']
# ['10009657', '10061173']
# ['10006825', '10037660', '10037884', '10047943']
# ['10013709']
# ['10069327', '10069889']
# ['10003997', '10059570']
# ['10054786']
# ['10035664']
# ['10013700', '10021789', '10037660', '10048948', '10052904']
# ['10017577', '10060933', '10065154']
# ['10033371']
# ['10019211']
# ['10003549', '10013709', '10016256', '10016322', '10016338', '10019211', '10061428']
# ['10018829']
# ['10019641', '10024429']
# ['10015929', '10022806', '10027091']
# ['10043414']
# ['10016450', '10017577', '10023215', '10031264', '10033371', '10041291', '10053156', '10057972']
# ['10013968']
# ['10005483', '10029155', '10069173', '10069221']
# ['10012174', '10013709', '10019211', '10025482', '10047700']
# ['10003239', '10042674']
# ['10012735']
# ['10000125']
# ['10003051', '10013781', '10052904']
# ['10003041', '10003046', '10003053']
# ['10044032']
# ['10003053']
# ['10008531', '10020642', '10047700']
# ['10012735', '10013709', '10022437', '10047895', '10051154']
# ['10000087', '10013709', '10014756', '10030104', '10030124', '10048961', '10061218', '10063161']
# ['10053762']
# ['10038470']
# ['10017412']
# ['10033425']
# ['10014011', '10014020', '10022061']
# ['10013709']
# ['10011781', '10019211', '10028813', '10036018']
# ['10019211']
# ['10021688']
# ['10003239', '10014184', '10037153', '10037153', '10061599']
# ['10013709', '10023230', '10033371']
# ['10022052', '10022052', '10022107', '10022107']
# ['10008479']
# ['10012735', '10019211', '10043521']
# ['10017533', '10017533']
# ['10022105', '10066210']
# ['10013709']
# ['10027951']
# ['10048959']
# ['10013709']
# ['10016803']
# ['10028810']
# ['10022052', '10022067', '10022086']
# ['10033474', '10046735', '10054786']
# ['10016256', '10033371']
# ['10013709']
# ['10040753', '10044034']
# ['10006451', '10040753']
# ['10046914', '10060945']
# ['10003239']
# ['10040753']
# ['10003239', '10013774', '10013781', '10016256', '10023232', '10037844', '10046914']
# ['10031252', '10035664', '10040872']
# ['10037087']
# ['10022086', '10054266']
# ['10011224', '10028735']
# ['10022052', '10022086']
# ['10022086', '10022093', '10022107', '10064355', '10069868']
# ['10022086', '10037153', '10064355', '10069868', '10073753']
# ['10002034', '10002544', '10013709', '10016173', '10016256', '10021519', '10024453', '10039073', '10040979', '10041823', '10062016']
# ['10022052', '10022067', '10022086']
# ['10022061', '10057362', '10069868']
# ['10003239', '10003549', '10013709', '10016256', '10028813', '10028813', '10033371', '10068319']
# ['10028810', '10037016', '10064265']
# ['10028116']
# ['10001949', '10013573', '10036960', '10051293']
# ['10007739', '10028334', '10043607']
# ['10003239']
# ['10040882', '10043607']
# ['10013709']
# ['10022061', '10022067', '10051572']
# ['10022062', '10022086', '10022093', '10051572']
# ['10035664']
# ['10012174', '10012735']
# ['10020751']
# ['10030041']
# ['10019063', '10061422']
# ['10012267']
# ['10012578', '10063829']
# ['10000081', '10003445', '10007882', '10047700']
# ['10037377', '10064687']
# ['10000081', '10002016', '10012174', '10012735']
# ['10013709']
# ['10046274']
# ['10053762']
# ['10045542', '10069853']
# ['10011906']
# ['10013573', '10028813']
# ['10025409']
# ['10036661']
# ['10022076']
# ['10028813', '10047700']
# ['10053762']
# ['10030942', '10047571']
# ['10033371', '10048959', '10053156', '10074693']
# ['10000059', '10013754', '10016173', '10019063', '10020642', '10020937', '10028813', '10033371', '10039906', '10049119']
# ['10017822', '10017955']
# ['10005750']
# ['10010305', '10012601', '10020635', '10024264', '10043458']
# ['10001760', '10049119', '10069326', '10069327']
# ['10027458', '10061309', '10067946']
# ['10012735', '10028813']
# ['10003549', '10012735', '10028813', '10047700']
# ['10011906']
# ['10011906']
# ['10020751', '10020751']
# ['10006924', '10071415']
# ['10043255']
# ['10022000', '10047942']
# ['10018100', '10028245']
# ['10008190', '10013554', '10055798']
# ['10008138']
# ['10001480', '10003239', '10043242', '10043951', '10047513']
# ['10013573', '10025482', '10040752']
# ['10011906']
# ['10000125', '10001488', '10001497', '10001540', '10001584', '10001606', '10001949', '10010144', '10010305', '10049119', '10050280']
# ['10005750']
# ['10011906']
# ['10011906']
# ['10012601', '10014141', '10025482', '10058080']
# ['10007559']
# ['10062344']
# ['10040047']
# ['10012735', '10052076']
# ['10013709']
# ['10013709', '10025482', '10048393', '10067484']
# ['10012735', '10028813', '10030963', '10047700']
# ['10003048', '10053762']
# ['10013700']
# ['10003591', '10008072', '10014625', '10029864', '10068357', '10070863']
# ['10003246']
# ['10011224', '10040753', '10047700', '10053123']
# ['10019211', '10024264', '10058467']
# ['10061105']
# ['10011906']
# ['10028596']
# ['10011906']
# ['10010305', '10076309']
# ['10003041', '10003055']
# ['10013573', '10023644', '10028813', '10076308']
# ['10013573', '10028813', '10043882']
# ['10011906', '10053762']
# ['10011906', '10053762']
# ['10011906']
# ['10011906']
# ['10013573']
# ['10008531', '10022052', '10022061', '10022062', '10022078', '10022079', '10022093', '10022107', '10028735', '10037660', '10053425']
# ['10010774', '10016256', '10017885', '10061428']
# ['10015915', '10047513', '10051116', '10052123', '10072342']
# ['10011906']
# ['10008190']
# ['10051592']
# ['10007649', '10008190', '10028596']
# ['10071043']
# ['10008190']
# ['10052086']
# ['10006147']
# ['10028596']
# ['10007559', '10008190']
# ['10028596']
# ['10028596']
# ['10028596']
# ['10008190']
# ['10008190']
# ['10028596']
# ['10008479', '10028596']
# ['10011906']
# ['10013700']
# ['10005393', '10005700']
# ['10000081', '10003239', '10037660', '10041206']
# ['10013554', '10048616', '10048832']
# ['10054236']
# ['10028596']
# ['10028596']
# ['10007515', '10008190']
# ['10007697', '10019974', '10021789', '10036769', '10061520', '10073411']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10007559', '10011078']
# ['10007559']
# ['10028372', '10039073']
# ['10040560']
# ['10012174', '10012671', '10033645', '10069339']
# ['10011906']
# ['10033425']
# ['10035226']
# ['10042609']
# ['10027599']
# ['10011906']
# ['10042530']
# ['10013654', '10070863']
# ['10053069', '10064355']
# ['10012374', '10016256', '10022052', '10022086', '10074859']
# ['10003552', '10015084', '10022079', '10022086', '10028521', '10042209', '10047513', '10059866']
# ['10022052', '10022052', '10022086', '10053425']
# ['10022086']
# ['10022086']
# ['10011224', '10016326', '10020642', '10028810', '10037660', '10043521']
# ['10006187', '10019304', '10020850', '10048782']
# ['10029410']
# ['10017944', '10018872', '10043417']
# ['10070925']
# ['10033425', '10051055']
# ['10013786', '10037087']
# ['10019974', '10035664']
# ['10035664']
# ['10022112', '10053425']
# ['10002855', '10013968', '10029331', '10033425', '10040829', '10041569', '10043071', '10047895']
# ['10012735', '10021097', '10028813', '10047700']
# ['10019727', '10072753']
# ['10025482']
# ['10061819']
# ['10044755']
# ['10012735', '10047700']
# ['10038683', '10061024']
# ['10013968', '10019303', '10030124', '10037377', '10051055', '10058990']
# ['10016322', '10040477']
# ['10013700']
# ['10013709']
# ['10003658', '10022000', '10035737']
# ['10027514', '10028334', '10064684']
# ['10053762']
# ['10017533']
# ['10067484']
# ['10011906']
# ['10003239']
# ['10029354', '10033661']
# ['10005750']
# ['10013781']
# ['10013709']
# ['10069405', '10076309']
# ['10005555', '10010305', '10012218', '10013887', '10013916', '10014387', '10016825', '10020772', '10024264', '10028521', '10040752', '10046543', '10048294', '10064373', '10070863']
# ['10010264', '10011732', '10016256', '10028411', '10028813', '10036790', '10037660']
# ['10057668']
# ['10000188', '10017600', '10018800', '10020737']
# ['10033295']
# ['10045542']
# ['10010774', '10062355']
# ['10075204']
# ['10001540', '10013983']
# ['10005483', '10005861']
# ['10016256', '10019211', '10037087']
# ['10008469']
# ['10016863', '10036590', '10037407', '10049771']
# ['10020937', '10039906']
# ['10013911']
# ['10013709']
# ['10013950', '10022998', '10034829', '10040984', '10068319']
# ['10007617']
# ['10054786']
# ['10067482', '10069327']
# ['10016256', '10060933']
# ['10048592']
# ['10028245']
# ['10013573', '10019211', '10034960']
# ['10000081', '10001928', '10001928', '10006298', '10013709', '10016322', '10018981', '10021033', '10028813', '10036567', '10036608', '10051641', '10054939']
# ['10005003']
# ['10046735']
# ['10011906']
# ['10013700', '10013789']
# ['10013786', '10015150', '10015946', '10015967', '10020568', '10037087', '10052140']
# ['10009866', '10017062']
# ['10005003']
# ['10005483']
# ['10001488', '10002368', '10002855', '10012218', '10012378', '10019063', '10022437', '10022998', '10041466', '10042458', '10072388']
# ['10024690']
# ['10035664']
# ['10024690']
# ['10009802', '10010774', '10017955', '10051055', '10053762', '10063743']
# ['10011906', '10021097', '10029404', '10047513', '10053762', '10058202']
# ['10016256', '10028813', '10033371', '10033645', '10033664', '10037660', '10047895']
# ['10006451', '10011224', '10013709', '10035664', '10047531', '10047571', '10048865']
# ['10020993', '10023676', '10069339']
# ['10029522']
# ['10028813', '10069226', '10069227', '10071134']
# ['10005728']
# ['10007559', '10067740']
# ['10008190']
# ['10007559', '10028596']
# ['10008190', '10028596']
# ['10011078', '10028596']
# ['10028596']
# ['10028596']
# ['10002388', '10007559', '10052086']
# ['10064961']
# ['10028596']
# ['10002388', '10028596', '10061024']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10007559']
# ['10011078']
# ['10007559', '10056370']
# ['10007559', '10010968']
# ['10007559']
# ['10007559']
# ['10019304', '10030124']
# ['10061024']
# ['10067482']
# ['10016256', '10017955', '10061589']
# ['10007559']
# ['10007559']
# ['10005169', '10007739', '10030095', '10037032', '10038867']
# ['10001480', '10003239', '10013573', '10016256', '10022052', '10024860', '10025482', '10028372', '10028411', '10033775', '10034879', '10037377', '10037410', '10037660', '10038687', '10042209', '10048393', '10049848', '10065369']
# ['10073508']
# ['10064538', '10067482', '10069327', '10069853']
# ['10011224', '10012735', '10030973', '10035598', '10037423', '10047700', '10061428']
# ['10013442']
# ['10001949', '10019465', '10020635', '10027374', '10061256']
# ['10012601', '10018651', '10043607', '10072268']
# ['10003239', '10003549', '10028411']
# ['10024690']
# ['10021097', '10036653']
# ['10011906', '10023424', '10038435', '10047895']
# ['10054112', '10073069']
# ['10019211', '10037855', '10044008', '10047571']
# ['10022061', '10022067', '10022107', '10039073', '10064355', '10066083']
# ['10006895', '10012174', '10021307', '10046572', '10047895', '10049438', '10058080', '10061273', '10062570', '10064687']
# ['10010305', '10020642', '10020993']
# ['10003827']
# ['10008629', '10024690']
# ['10005081', '10037660']
# ['10003983', '10013709', '10016322', '10020937', '10041349', '10061021']
# ['10019196']
# ['10007882', '10021789', '10033371', '10037153', '10041662', '10050473']
# ['10028411']
# ['10011906', '10016256', '10058467']
# ['10002855', '10008190', '10010305', '10056812']
# ['10006451', '10011224', '10035664', '10037660']
# ['10004272', '10051139']
# ['10034023']
# ['10012601', '10049438', '10050513', '10055798', '10061818']
# ['10009900']
# ['10011906']
# ['10000081', '10013709', '10021789', '10022116', '10046810', '10049438', '10063130', '10072878']
# ['10013709']
# ['10001946', '10052450']
# ['10003658', '10076308']
# ['10018985']
# ['10016173', '10047340']
# ['10013709', '10043417', '10048561']
# ['10011906']
# ['10010254', '10016173', '10035664', '10037423', '10061126', '10061599']
# ['10005186', '10007739']
# ['10008469', '10008479', '10013709', '10013968', '10016256', '10028810', '10036790', '10036790', '10037400']
# ['10025482', '10028596', '10049438']
# ['10013496', '10013654', '10013663', '10013710', '10013754', '10016256', '10053762', '10064355']
# ['10000060', '10010774', '10012601', '10060891', '10061024', '10063382']
# ['10000087']
# ['10010071', '10013442', '10055798', '10057765', '10074065']
# ['10009192']
# ['10002855', '10003658', '10003988', '10011469', '10012378', '10016256', '10020772', '10022437', '10043607']
# ['10010305', '10013709', '10017577', '10041243', '10062254']
# ['10002855', '10005839', '10008629', '10012378', '10014326', '10014328', '10014994', '10017822', '10019842', '10024419', '10031060', '10039956', '10040477', '10041823', '10051589', '10057668', '10061461', '10063797', '10063797']
# ['10067585']
# ['10021789']
# ['10039073']
# ['10008589', '10011224', '10015090', '10022437', '10028024', '10037660', '10042434', '10047700', '10053459', '10053762', '10076309']
# ['10003285']
# ['10006451', '10035664']
# ['10015090']
# ['10037844']
# ['10016334', '10018388', '10057372']
# ['10023232', '10033371', '10037660', '10037855', '10054786']
# ['10012374', '10013709', '10028334']
# ['10013709', '10069327']
# ['10054112']
# ['10011224', '10052251']
# ['10005186', '10047531']
# ['10014004', '10028662']
# ['10001497', '10016256', '10042209', '10047095', '10047184']
# ['10003549', '10016256', '10025482']
# ['10061024']
# ['10013935', '10027313']
# ['10005169', '10064930']
# ['10040880']
# ['10005750', '10016256', '10019211']
# ['10013968', '10033295']
# ['10005396']
# ['10023874', '10040753']
# ['10016173', '10028813', '10061225']
# ['10013781', '10013950']
# ['10013754']
# ['10016256', '10050584']
# ['10002965']
# ['10002855', '10012378', '10013709', '10016344', '10033664', '10042209', '10069326', '10069327']
# ['10070863', '10074903']
# ['10070863', '10074903']
# ['10070863']
# ['10000381', '10000804', '10001597']
# ['10035664']
# ['10047942']
# ['10035226']
# ['10033661']
# ['10017533']
# ['10013709']
# ['10013654']
# ['10010144']
# ['10019211', '10024264']
# ['10022052', '10022061', '10022093', '10022094', '10022095', '10022112', '10053425']
# ['10013573', '10015535', '10020642', '10021567', '10024137', '10033557', '10040589', '10061422']
# ['10047942']
# ['10055798']
# ['10022437']
# ['10011224', '10013968', '10024570', '10037844', '10037884']
# ['10007515', '10047290']
# ['10011906', '10013654']
# ['10019211', '10036018', '10046494']
# ['10003988', '10016256', '10019211', '10020937', '10025482']
# ['10043607']
# ['10013709', '10035526']
# ['10008479', '10028372', '10028411']
# ['10010356', '10071404']
# ['10011906', '10074903']
# ['10000050', '10022687']
# ['10019211']
# ['10049548', '10076309']
# ['10061962']
# ['10025482', '10061852']
# ['10021789', '10028596']
# ['10016173', '10031127']
# ['10022000']
# ['10022061', '10022095', '10030942', '10048393']
# ['10069405']
# ['10028653', '10029719', '10040829']
# ['10002855']
# ['10065485', '10065984']
# ['10018884']
# ['10019465', '10028035', '10033775', '10040030']
# ['10072720']
# ['10072931']
# ['10012578']
# ['10008469', '10008479', '10011224', '10033557']
# ['10003553', '10035664']
# ['10003054', '10050104']
# ['10013709']
# ['10013709']
# ['10013654']
# ['10018884', '10035528', '10046274', '10052211']
# ['10008796', '10016102', '10019717', '10024670', '10028813', '10037087', '10058117']
# ['10010305', '10013968', '10015037', '10025482']
# ['10062546', '10074903']
# ['10039906']
# ['10022067']
# ['10022086', '10028813', '10028813', '10038776', '10047700', '10061148']
# ['10015946', '10052143']
# ['10033661']
# ['10022061', '10022095']
# ['10009033', '10013968', '10047899']
# ['10055113']
# ['10005191']
# ['10005191', '10016173', '10019974', '10028780', '10040047', '10042128', '10049848', '10050584']
# ['10012735', '10024855', '10025482']
# ['10024670']
# ['10033371']
# ['10022086', '10064355', '10069868']
# ['10000081', '10012735', '10016256']
# ['10000059', '10000087', '10001497', '10002368', '10002855', '10014551', '10014551', '10016256', '10022004', '10025482', '10028813', '10028813', '10033371', '10040753']
# ['10003239', '10023230', '10028810']
# ['10011224', '10022052', '10028810', '10052251', '10053459', '10068319']
# ['10011469', '10047571']
# ['10022086']
# ['10000081']
# ['10023874', '10062355']
# ['10016256', '10028813', '10033546', '10047700']
# ['10010741', '10040742', '10057392']
# ['10005425', '10005861', '10011968', '10016256', '10017788', '10025482', '10046571']
# ['10066409']
# ['10013573', '10022086']
# ['10029366', '10029366', '10035528']
# ['10003658', '10046571']
# ['10007509', '10013968']
# ['10013774', '10013781']
# ['10017822', '10055798', '10064658']
# ['10013709', '10028334', '10037012', '10061822']
# ['10043414']
# ['10013709', '10053762']
# ['10035222']
# ['10051055']
# ['10022086']
# ['10054112']
# ['10003549', '10007739', '10027175', '10028411', '10039119']
# ['10009887', '10012735', '10023003', '10051589', '10056979']
# ['10046914', '10076309']
# ['10003402', '10055798', '10058284']
# ['10013709', '10076309']
# ['10012578']
# ['10028596']
# ['10013968', '10016256', '10023232', '10048959', '10076308']
# ['10000060', '10001760', '10002855', '10008479', '10011971', '10012378', '10013754', '10016322', '10019211', '10022437', '10027940', '10028813', '10033557', '10033775', '10040799', '10047924', '10076309']
# ['10002034', '10012735', '10047700']
# ['10001497', '10010305', '10013968', '10020660', '10023676', '10027417', '10040560', '10069339', '10070863']
# ['10012735', '10037660', '10039906', '10047461', '10047700']
# ['10001480', '10042128', '10063672']
# ['10005814']
# ['10073317']
# ['10013700', '10028411']
# ['10010305']
# ['10019303']
# ['10005052', '10029446']
# ['10000496', '10001508', '10013709', '10013952', '10020937', '10044565', '10049848', '10061296']
# ['10069327', '10070691']
# ['10047899']
# ['10022773']
# ['10000059', '10012735', '10016173', '10016970']
# ['10013709']
# ['10013709', '10020772']
# ['10009887', '10019211', '10022437']
# ['10028116', '10029354']
# ['10003239', '10003988', '10005191', '10018735', '10028411', '10037844', '10037855']
# ['10020802']
# ['10005839', '10024910']
# ['10028813', '10047700']
# ['10061024']
# ['10003658', '10053762', '10061024']
# ['10010984', '10015683', '10036595', '10036603', '10071389', '10071408']
# ['10028813']
# ['10036807', '10065042']
# ['10002034', '10003549', '10012735', '10019663', '10022687', '10029331', '10043414', '10061818']
# ['10064658']
# ['10000081', '10002368', '10002855', '10008479', '10010144', '10010774', '10011781', '10013573', '10018836', '10018870', '10019211', '10020642', '10024855', '10028035', '10028372', '10029412', '10033664', '10043706', '10047571', '10047899', '10068319']
# ['10003549', '10011953', '10013573', '10016173', '10022437', '10034010', '10039203', '10048948']
# ['10012735', '10016766']
# ['10015150', '10037087', '10040880']
# ['10016454', '10020603', '10020772', '10020772', '10021015', '10033425', '10034341', '10048861', '10054088']
# ['10019211']
# ['10002383', '10003239', '10003285', '10003988', '10008479', '10016173', '10017577', '10028300', '10028372', '10028411', '10033371', '10033425', '10067620', '10072005']
# ['10006451', '10020937', '10029174']
# ['10005003']
# ['10011906']
# ['10011906']
# ['10006187']
# ['10018852']
# ['10022061', '10037087']
# ['10021789']
# ['10012174']
# ['10000059', '10013573', '10061164']
# ['10005003']
# ['10039424']
# ['10040108']
# ['10013036', '10020937', '10027175', '10028334', '10046543', '10048393', '10061425']
# ['10028245', '10033892', '10046543']
# ['10047942']
# ['10003239', '10018627']
# ['10011906']
# ['10001949', '10008196', '10012373', '10012378', '10013710', '10019063', '10022437', '10027951', '10029412', '10033664', '10036316', '10040108', '10041347', '10042458', '10042772', '10047340', '10047571', '10061422', '10061920', '10070863']
# ['10005003']
# ['10012735', '10019211', '10028813']
# ['10015993', '10024570']
# ['10033371', '10037153', '10037867', '10040831', '10062355']
# ['10005003']
# ['10013709']
# ['10037844']
# ['10033371']
# ['10054112']
# ['10013968']
# ['10055798', '10060933']
# ['10019133']
# ['10011906']
# ['10069326', '10069327']
# ['10006002']
# ['10029354']
# ['10050513', '10061818']
# ['10013700', '10037844', '10046735']
# ['10000081', '10007515', '10017533', '10017866', '10017955', '10017982', '10040070', '10049150', '10050456', '10060945']
# ['10013700']
# ['10028836']
# ['10029148', '10061574']
# ['10013709', '10069326']
# ['10044755', '10076309']
# ['10012267']
# ['10007515', '10007636']
# ['10003041', '10054838', '10066149']
# ['10013036', '10042159']
# ['10003988', '10033425', '10066371']
# ['10002034', '10012735', '10047895', '10061428', '10061664']
# ['10010305', '10013573', '10014551', '10025482', '10028813', '10033775', '10047513']
# ['10046910']
# ['10013036', '10047513']
# ['10002329', '10006895', '10010774', '10011906', '10013968', '10025197', '10027457', '10027458', '10027459', '10033371', '10038695', '10048667', '10061428']
# ['10011906', '10053762']
# ['10011906', '10053762']
# ['10011906']
# ['10003011', '10007586', '10011219', '10012378', '10013968', '10014625', '10015958', '10018075', '10033666', '10034912', '10035598', '10039722', '10047289', '10057667', '10058080', '10071404', '10073485']
# ['10016256', '10016322', '10017577', '10046571', '10047940', '10065154']
# ['10003553', '10005591', '10021403', '10028372', '10029331', '10029883', '10041591', '10060860', '10061312']
# ['10048561', '10053648']
# ['10028596']
# ['10008190']
# ['10028596']
# ['10011078', '10028596']
# ['10008190']
# ['10007559', '10008190']
# ['10011078', '10028596']
# ['10011086']
# ['10028596']
# ['10011078']
# ['10028596']
# ['10008190']
# ['10011078', '10042604']
# ['10007559']
# ['10061024']
# ['10007559', '10007559']
# ['10007559']
# ['10007559']
# ['10011078']
# ['10007559', '10051592']
# ['10061024']
# ['10025031']
# ['10016803', '10047899', '10049040']
# ['10039203', '10047513']
# ['10001949', '10001949', '10003119', '10010264', '10013700', '10014363', '10021114', '10022437', '10027313', '10028411', '10031161', '10033371', '10041591', '10041591', '10046910', '10047513', '10047899', '10048334', '10048334', '10048439', '10049470', '10050256', '10052302']
# ['10005192', '10007882', '10017711', '10022694', '10024774', '10039906', '10040047', '10051714', '10062070', '10063914', '10069568']
# ['10039906']
# ['10033425', '10033425', '10037844']
# ['10025327']
# ['10043414', '10064366', '10069327']
# ['10013709', '10013968', '10069327']
# ['10009033', '10010968', '10011906', '10038435']
# ['10001854', '10012174', '10020993', '10061428']
# ['10049054', '10074941']
# ['10049054', '10074941']
# ['10013709', '10013968', '10033318']
# ['10049054', '10074941']
# ['10002948', '10016173', '10023874', '10025482', '10027175', '10049848', '10061599']
# ['10033645', '10047700']
# ['10000081', '10003549', '10005191', '10011906', '10013786', '10018836', '10018879', '10020649', '10023799', '10028813', '10040831', '10043417', '10058898', '10061818', '10067946']
# ['10005780', '10012378', '10013573', '10021097', '10024855', '10027951', '10039083', '10040744', '10040753', '10040753', '10041349', '10049040']
# ['10038428']
# ['10016173']
# ['10008190', '10012735']
# ['10011732']
# ['10000234', '10049550', '10073513']
# ['10048038']
# ['10003988']
# ['10013968', '10013971', '10058467', '10061011', '10065154']
# ['10011906', '10013654']
# ['10027175']
# ['10060933']
# ['10037087']
# ['10029282']
# ['10029783', '10030124', '10074969']
# ['10016173', '10018884', '10035528', '10047942']
# ['10022067', '10022086']
# ['10022086']
# ['10012735', '10016766', '10023232', '10048959']
# ['10013709']
# ['10013709', '10047899', '10061581']
# ['10000087', '10013990', '10048994']
# ['10047899']
# ['10039073']
# ['10022061', '10022094', '10066044']
# ['10019211', '10028813']
# ['10062355']
# ['10013709', '10069327']
# ['10041349']
# ['10002034', '10002942', '10003549', '10006312', '10008469', '10012374', '10020642', '10033371', '10042674', '10049872', '10060800', '10061472']
# ['10005814']
# ['10005688', '10047899']
# ['10016123', '10025394', '10036485', '10073513']
# ['10005750', '10013968', '10037844']
# ['10000060', '10013946']
# ['10005557']
# ['10033371', '10033775']
# ['10013781', '10019211']
# ['10005956', '10043709']
# ['10005393', '10044565']
# ['10028334', '10063910']
# ['10000087']
# ['10013709', '10049414', '10054112']
# ['10021097', '10033557']
# ['10002855', '10025482']
# ['10000087', '10002424', '10018291', '10019211', '10024570', '10028411', '10042682', '10046735', '10074403']
# ['10006451']
# ['10019300']
# ['10039101']
# ['10029202']
# ['10006002', '10013709']
# ['10013968', '10069327', '10072878']
# ['10019211']
# ['10067398']
# ['10006093', '10013654', '10033295', '10033318']
# ['10011906']
# ['10035664']
# ['10047700']
# ['10046735']
# ['10005003']
# ['10020937', '10047555']
# ['10009944']
# ['10013654', '10058709']
# ['10022437', '10070747']
# ['10012174']
# ['10013709']
# ['10007515', '10011906', '10020772', '10021097', '10022840', '10047302', '10053762', '10064355']
# ['10000081', '10001497', '10007632', '10014418', '10017944', '10019211', '10020642', '10021328', '10021639', '10022611', '10024378', '10028813', '10029331', '10033661', '10033775', '10037423', '10037660', '10041660', '10047700', '10052015', '10061273']
# ['10011906']
# ['10003658', '10008479', '10011224', '10012735', '10013968', '10019304', '10033557', '10038776', '10047513', '10047700']
# ['10012578']
# ['10027480']
# ['10011906', '10021789']
# ['10013786', '10027458', '10035664', '10053762']
# ['10016288']
# ['10016173']
# ['10002942', '10007739', '10012378', '10013573', '10013573', '10020937', '10028813', '10047899']
# ['10001949', '10002855', '10012378', '10018100', '10034759', '10039906']
# ['10008479', '10028596']
# ['10003658', '10011078', '10028596']
# ['10008190']
# ['10000496', '10006784', '10015150', '10016825', '10019194', '10019211', '10027599', '10028411', '10037087', '10054786']
# ['10028596']
# ['10007559', '10028596']
# ['10028596']
# ['10008190']
# ['10000891']
# ['10000891']
# ['10028596']
# ['10007559', '10008479']
# ['10007559', '10007617']
# ['10008190', '10061024']
# ['10007559', '10008479', '10061024']
# ['10006002', '10016256', '10061394']
# ['10003011', '10008190', '10016256', '10017577', '10024855', '10030345', '10033132', '10033157', '10049848', '10052904']
# ['10049418']
# ['10007559']
# ['10002034', '10003549', '10003658', '10006451', '10007554', '10009033', '10013968', '10013971', '10016803', '10017955', '10018884', '10019211', '10030124', '10033433', '10037423', '10042674', '10047899', '10048961', '10066152']
# ['10007559']
# ['10007559']
# ['10003239', '10003988', '10017577', '10028372', '10028411', '10033425']
# ['10020642', '10025482', '10042772']
# ['10000125', '10028813', '10047700']
# ['10013700', '10037844', '10046735']
# ['10008469', '10013573', '10013709', '10020642', '10028836', '10069327']
# ['10013709', '10033295', '10069327']
# ['10035226']
# ['10015218', '10042772']
# ['10000081', '10000188', '10001497', '10002383', '10002855', '10003549', '10003988', '10008479', '10013082', '10013573', '10013781', '10019211', '10019303', '10019304', '10020642', '10022086', '10022437', '10024670', '10028334', '10028411', '10028813', '10033295', '10033557', '10034962', '10038743', '10041349', '10042458', '10044565', '10047513', '10052904', '10053762', '10058911', '10061224', '10061428', '10067125', '10071151', '10075265']
# ['10000234']
# ['10025028', '10035598', '10035669']
# ['10013700', '10047700']
# ['10005557', '10073069']
# ['10039906']
# ['10005470']
# ['10040808']
# ['10029410', '10036030', '10040968', '10047943', '10050551']
# ['10025080', '10035598', '10035664']
# ['10014561', '10033670', '10053762', '10074903']
# ['10022523', '10069327']
# ['10022116', '10033371', '10046810', '10053762', '10069868']
# ['10068789']
# ['10001497', '10002368', '10013754', '10020642', '10022437', '10022998', '10027951', '10028813', '10029412', '10033664', '10033775', '10042458', '10047340']
# ['10019663', '10023126', '10049438', '10069339']
# ['10002199', '10009192']
# ['10007882']
# ['10011906']
# ['10012578']
# ['10013654']
# ['10037377']
# ['10003239', '10013968', '10016256', '10028411', '10040943', '10042674']
# ['10064658', '10076454']
# ['10013950', '10067954']
# ['10012578', '10033371', '10061178']
# ['10012578']
# ['10008748', '10013709']
# ['10037844', '10067868']
# ['10008469']
# ['10003239', '10008479', '10028334', '10033425', '10066371']
# ['10037844']
# ['10060820', '10061225']
# ['10003239', '10017577', '10020642', '10022086', '10023232', '10033425', '10048959']
# ['10010144', '10070863']
# ['10044016']
# ['10013700']
# ['10037844']
# ['10001760', '10003239', '10003549', '10033557', '10034912', '10047340']
# ['10067585']
# ['10033425']
# ['10011906']
# ['10067723']
# ['10063785']
# ['10011010', '10013710']
# ['10005557', '10029148', '10038435']
# ['10028641']
# ['10022067', '10033425', '10043224']
# ['10013709', '10016256', '10041349']
# ['10006482', '10011224', '10039424', '10051171']
# ['10001497', '10037087']
# ['10051055', '10058279', '10058992']
# ['10028836']
# ['10000059', '10025482']
# ['10011906', '10027091']
# ['10011224', '10028735', '10052251']
# ['10012218', '10066431']
# ['10044565']
# ['10000081', '10005191', '10011224', '10013968', '10016256', '10030095', '10030124', '10033425', '10037844']
# ['10011224', '10013968', '10019211', '10025482', '10028391', '10028735', '10065154', '10068319']
# ['10061818', '10067450', '10076309']
# ['10028596', '10062599']
# ['10036018', '10046555']
# ['10072268']
# ['10006093', '10028810', '10034498', '10035664']
# ['10048959', '10067594']
# ['10013082']
# ['10003549', '10016256', '10025482', '10028810', '10066901']
# ['10011906']
# ['10041347']
# ['10028810', '10033557', '10033775', '10039073', '10046910', '10047461', '10061549', '10068319']
# ['10011906']
# ['10012735', '10024855', '10028116', '10030997', '10031009', '10037660', '10037844', '10042128', '10047700', '10068319']
# ['10013663', '10036316', '10066169']
# ['10005910', '10010305', '10013968', '10029410', '10030041', '10033557', '10034336', '10034568', '10037532', '10039906', '10043306', '10043882', '10047654', '10067967']
# ['10010264', '10067152']
# ['10023874', '10028810']
# ['10011906']
# ['10016173', '10048049', '10049848']
# ['10002199']
# ['10013709']
# ['10051398']
# ['10007515', '10013654', '10038669']
# ['10011906', '10013654']
# ['10010144', '10011906']
# ['10005483', '10005839', '10013573', '10013578', '10016256', '10020060', '10022067', '10022086', '10030124', '10037660', '10038743', '10043882', '10047340', '10047513', '10047674', '10048964', '10049816', '10051589', '10058046']
# ['10007515', '10036000', '10038669']
# ['10013786', '10040844']
# ['10007554', '10030095']
# ['10013654', '10061355']
# ['10013709', '10021118', '10047899']
# ['10037660']
# ['10019211', '10035664', '10039101', '10039509', '10040753', '10040844', '10062545']
# ['10054107']
# ['10025482']
# ['10016256', '10019211']
# ['10025482']
# ['10008190']
# ['10003549', '10011224', '10013573', '10013781', '10013968', '10015090', '10016256', '10019211', '10020937', '10023644', '10029331', '10029354', '10033425', '10033775', '10034960', '10039083', '10039101', '10040030', '10048959', '10049274']
# ['10013709']
# ['10028335', '10028347', '10034636', '10044565']
# ['10024421', '10033888', '10055004', '10070240']
# ['10011906', '10037660', '10048334', '10067011']
# ['10041101']
# ['10011906', '10013968', '10042609', '10047184', '10061105']
# ['10013700', '10018092', '10037087']
# ['10001497', '10013654', '10020937']
# ['10023439', '10066261', '10066262', '10074495']
# ['10022086', '10069868']
# ['10012601']
# ['10002855', '10037884', '10053425']
# ['10000087', '10008531', '10018852', '10022061', '10022061', '10022075', '10022075', '10022093', '10033425']
# ['10037162']
# ['10014184', '10019974', '10033371']
# ['10029883']
# ['10013700']
# ['10003239', '10043607']
# ['10040882']
# ['10016322', '10021789', '10022061', '10022095', '10053425']
# ['10001760', '10012378', '10022437']
# ['10000060', '10019211', '10022437', '10028411', '10038776', '10041349', '10048334', '10052904']
# ['10016173', '10036807']
# ['10016173', '10020100', '10052428']
# ['10009900', '10022086', '10022086', '10022086', '10064355', '10064355', '10064355', '10069868', '10069868', '10069868']
# ['10022086']
# ['10073317']
# ['10062355', '10073317', '10073513']
# ['10013700']
# ['10043607']
# ['10000496', '10013573', '10018836', '10019303', '10019304', '10061623']
# ['10031161', '10039073', '10044565', '10048959']
# ['10018985']
# ['10011906', '10013709', '10052804']
# ['10002855', '10011469', '10022086']
# ['10005911', '10021789', '10052252', '10068319']
# ['10025482']
# ['10033371']
# ['10022000', '10028810']
# ['10003399', '10022093', '10022094', '10037087', '10066044']
# ['10016173', '10019114']
# ['10048737']
# ['10058080']
# ['10020772', '10067671']
# ['10003239']
# ['10022086']
# ['10023469', '10024690']
# ['10037844']
# ['10072736']
# ['10037153', '10037162', '10037884']
# ['10022086', '10066044']
# ...
# ['10013709', '10016338', '10037211']
# ['10013710', '10013983']
# ['10003988']
# ['10000081', '10012735', '10028813']
# ['10061623']
# ['10023874', '10025482', '10028836']
# ['10015929']
# ['10013952', '10019211', '10027566']
# ['10028034', '10031009', '10047924']
# ['10019211', '10025482', '10029216', '10061428']
# ['10000060', '10033371']
# ['10000060', '10022052', '10022061']
# ['10013709']
# ['10046571']
# ['10025482', '10028813', '10033425', '10047700']
# ['10010264', '10011005', '10013709', '10019211']
# ['10010071', '10027417', '10033295', '10038661', '10070863']
# ['10067482', '10076573']
# ['10035664']
# ['10052016']
# ['10013709', '10053191']
# ['10072378']
# ['10012735', '10026882', '10028140', '10033425', '10049101']
# ['10000060', '10003445', '10019663', '10028289', '10047895']
# ['10042682']
# ['10008479', '10013654', '10066053']
# ['10051398', '10053762']
# ['10010264']
# ['10006784', '10023232', '10033775', '10037087', '10048959']
# ['10053762', '10061818']
# ['10022437', '10061613']
# ['10013709']
# ['10013968', '10014387', '10014395', '10021114', '10028600', '10042464']
# ['10014166', '10027514', '10033371']
# ['10010264', '10019211', '10027599', '10028836', '10034759', '10034960', '10047513']
# ['10075192']
# ['10006825', '10008190', '10010305', '10019211', '10035664', '10047115', '10049187']
# ['10011224', '10052251', '10061736']
# ['10008611', '10009887', '10013538', '10013554', '10019022', '10019708', '10020028', '10022687', '10025476', '10029148', '10030216', '10045285', '10046555', '10056819', '10061529', '10061998']
# ['10013700', '10057970']
# ['10013654', '10037211']
# ['10054112']
# ['10013700', '10037844', '10064687']
# ['10011224', '10012735', '10013709', '10013968', '10015090', '10018840', '10025256', '10028813', '10029368', '10038155', '10046735', '10061428', '10067152']
# ['10051077', '10064882']
# ['10011224', '10021036', '10025482']
# ['10008190', '10025482']
# ['10016256']
# ['10027175', '10043224']
# ['10011906', '10016173', '10022116']
# ['10027091']
# ['10005557', '10018478']
# ['10020772', '10048439', '10052920', '10076309']
# ['10024384', '10025327', '10029354']
# ['10028034']
# ['10005746', '10016256', '10019211']
# ['10000087', '10003239', '10007586', '10012378', '10016256', '10023232', '10025258', '10027880', '10028411', '10028810', '10035528', '10036790', '10040907', '10047899', '10047943']
# ['10003239', '10006002', '10011224', '10016256', '10028334', '10028411', '10028810', '10028813', '10035742', '10037383', '10037660', '10048959']
# ['10033557']
# ['10003549', '10013573', '10048959', '10073085']
# ['10037377', '10051055']
# ['10052285']
# ['10016173', '10022595', '10022758', '10042316', '10068357']
# ['10001760']
# ['10022116']
# ['10022116']
# ['10022116']
# ['10013573', '10013709', '10028813', '10047700']
# ['10012373', '10012735', '10028813']
# ['10020947', '10021027']
# ['10012735', '10019211', '10028813']
# ['10000087', '10010264']
# ['10008118']
# ['10019022', '10022081']
# ['10019717', '10028813', '10037660', '10046735', '10049438']
# ['10036556']
# ['10039491']
# ['10000081', '10012735', '10028813', '10047700']
# ['10022061', '10022094', '10022095', '10046306', '10053425']
# ['10020646']
# ['10010774']
# ['10010774']
# ['10037844']
# ['10011906', '10070863']
# ['10005557', '10047513', '10061219']
# ['10020100', '10033307', '10033647']
# ['10013710', '10062014']
# ['10002034', '10002855', '10002915', '10012735', '10017693', '10024384', '10025327', '10028116', '10028813', '10029354', '10036142', '10043554', '10054207', '10058080']
# ['10061920']
# ['10005557']
# ['10010264', '10013709']
# ['10016165', '10016256', '10021097', '10024384', '10029354']
# ['10019049', '10069228']
# ['10013709']
# ['10013709', '10069327']
# ['10013709']
# ['10019030']
# ['10019030', '10069327']
# ['10001760', '10019049']
# ['10013709', '10019044']
# ['10001760']
# ['10002556', '10003239', '10017577', '10033425', '10042609', '10072163']
# ['10013573', '10021097', '10048561', '10053762']
# ['10022972']
# ['10013573']
# ['10064385']
# ['10003677', '10010305', '10014387', '10024855']
# ['10027336']
# ['10002855', '10012735', '10013573', '10013754', '10016256', '10019211', '10020642', '10022437', '10022998', '10028813', '10029412', '10033775', '10039906', '10040026', '10042458', '10047340', '10047700']
# ['10018358']
# ['10013709']
# ['10072878']
# ['10046571', '10054236']
# ['10012735', '10016100']
# ['10012735', '10017918', '10019211', '10025482', '10028813']
# ['10039491']
# ['10069297']
# ['10003118', '10016035', '10029769', '10073513']
# ['10039906', '10053762', '10064355']
# ['10061598']
# ['10060862']
# ['10008190']
# ['10015150', '10021688', '10029331', '10048886', '10062713']
# ['10019974']
# ['10001949', '10021654', '10047899', '10061822']
# ['10013911', '10034018']
# ['10061623']
# ['10016256', '10022437']
# ['10039674', '10040986']
# ['10019211']
# ['10048941', '10050104']
# ['10006451', '10006938', '10019211']
# ['10012735']
# ['10020942', '10037032']
# ['10000081', '10003549', '10003988', '10014011', '10017577', '10019974', '10020642', '10037660', '10040753', '10062352']
# ['10019211']
# ['10016059']
# ['10015946', '10022004', '10023644', '10025169', '10052140', '10065154']
# ['10000087', '10008531', '10012735', '10020642', '10028813', '10047700', '10065154']
# ['10012735', '10065154']
# ['10003549', '10019211', '10022004', '10028411']
# ['10010774', '10049084']
# ['10065154']
# ['10012735']
# ['10002855', '10008611', '10012378', '10013559', '10013573', '10017626', '10017822', '10017885', '10019646', '10025476']
# ['10015916', '10019303']
# ['10000060', '10046555']
# ['10006187']
# ['10002515', '10007882', '10015150', '10016334', '10048961']
# ['10019670', '10035528', '10035664', '10037400', '10061471']
# ['10036543', '10061188', '10062173']
# ['10005724', '10005725', '10007558', '10008796', '10010305', '10011906', '10013968', '10013971', '10016173', '10016256', '10019304', '10021097', '10024968', '10030095', '10030124', '10033425', '10037423', '10040799', '10046571', '10046571', '10050584', '10050778', '10050819', '10061024', '10062117', '10062355', '10062355', '10070379', '10073354']
# ['10016256', '10033371', '10035528']
# ['10003988', '10008479', '10015090', '10022437', '10029366', '10033371', '10036790', '10047942', '10052968', '10057392']
# ['10007882', '10042674', '10048959', '10061218']
# ['10035598']
# ['10001760', '10003011', '10011781', '10016256', '10033132', '10041349', '10046571', '10052904', '10057668', '10061224']
# ['10008190']
# ['10000087', '10035598', '10035664', '10038428', '10060945']
# ['10064687']
# ['10000081', '10009657', '10010305', '10016288', '10021036']
# ['10002368', '10035528']
# ['10003549', '10005750', '10012174', '10013573', '10013781', '10013789', '10015150', '10019303', '10022086', '10029216', '10044565', '10047571', '10047895', '10060800']
# ['10036600', '10036608', '10073513']
# ['10008118', '10012601']
# ['10003553', '10013968', '10022998', '10025482', '10028810', '10033132', '10053069', '10065154']
# ['10033425', '10055123']
# ['10016322', '10028997', '10057840', '10076573']
# ['10025650', '10040753', '10062352']
# ['10067482']
# ['10013573', '10016256', '10018800', '10020751', '10028653', '10030041', '10043431', '10043913', '10047899', '10054112', '10060933', '10061224']
# ['10072731']
# ['10029366', '10047942', '10047942']
# ['10000059', '10000381', '10019211']
# ['10003285', '10006784', '10006784', '10010264', '10013709', '10029223', '10033371', '10052804', '10076711']
# ['10003549', '10048334']
# ['10037884']
# ['10067585']
# ['10035598', '10038695']
# ['10003553', '10006451']
# ['10038848', '10061852', '10064355', '10069868', '10076573']
# ['10005483', '10018358']
# ['10011469', '10018870', '10020765', '10020772', '10023424', '10025482', '10042209', '10062226', '10068319']
# ['10047786', '10067641', '10069327']
# ['10002855', '10003549', '10022116', '10029216', '10033371', '10036086', '10049119', '10064684', '10071368']
# ['10033775', '10040753']
# ['10003549', '10010774', '10013709', '10016173', '10027091', '10027175', '10028200', '10048049', '10049848', '10050584']
# ['10039203', '10050296']
# ['10067482', '10074902']
# ['10019211', '10030124', '10051290']
# ['10064355', '10069868']
# ['10000090', '10012735', '10020642', '10028813', '10036653', '10039424']
# ['10062770']
# ['10003041', '10003053', '10003055', '10049042']
# ['10072878']
# ['10011906']
# ['10057268', '10058571']
# ['10021789']
# ['10021789']
# ['10012578']
# ['10039163']
# ['10002198', '10008469', '10012735']
# ['10017533', '10047895']
# ['10000090', '10005557', '10013968', '10016256', '10017577', '10018484', '10047899']
# ['10007617', '10013709', '10021789', '10035528', '10037660', '10047895', '10049438', '10051814', '10061324', '10063743']
# ['10013573']
# ['10042609', '10055798']
# ['10027727']
# ['10002034', '10025183', '10025482', '10028813', '10033661', '10037660', '10061428', '10061472', '10062237']
# ['10012378']
# ['10012824', '10061850']
# ['10029148']
# ['10005734']
# ['10070863']
# ['10012735', '10013968', '10061428']
# ['10002855', '10003399', '10013911', '10016256', '10025482', '10028813', '10029410', '10033425', '10033664', '10037844', '10040047', '10043071', '10061428', '10063743']
# ['10003239', '10016256', '10029223', '10033425']
# ['10010264', '10012735', '10028813', '10061148']
# ['10052251']
# ['10041662']
# ['10011224', '10035676', '10073755']
# ['10022094', '10022095', '10053425']
# ['10003239', '10016338', '10022437', '10022998', '10029216', '10030095', '10047899', '10054112']
# ['10016807', '10042772', '10061024']
# ['10000060']
# ['10055798']
# ['10013709', '10033132']
# ['10019717', '10022611']
# ['10016803']
# ['10019974']
# ['10012578']
# ['10012578']
# ['10002034', '10003553', '10006451', '10006482', '10012735', '10027091', '10028813', '10030963', '10042772', '10047700']
# ['10051118']
# ['10013709', '10069327']
# ['10002368', '10022998', '10060800']
# ['10000060', '10003983', '10003988', '10005750', '10010264', '10013946', '10015137', '10016766', '10017944', '10019211', '10023003', '10028391', '10028813', '10038428', '10047700', '10048334', '10061428']
# ['10011906', '10070863']
# ['10011906', '10061818']
# ['10025482']
# ['10010071', '10019660']
# ['10025183']
# ['10064684']
# ['10000059']
# ['10022067']
# ['10003239', '10006002', '10019974', '10028334', '10033425', '10037867', '10040984']
# ['10022052', '10050584']
# ['10022067']
# ['10005396', '10022086', '10027091']
# ['10011906']
# ['10003239', '10003549', '10003988', '10004412', '10010774', '10028334', '10028372']
# ['10000891', '10011091', '10033371', '10037423']
# ['10001760', '10003239', '10003988', '10006451', '10008469', '10013990', '10016322', '10018867', '10033371', '10033425', '10040753', '10066454']
# ['10013950', '10020751', '10043528']
# ['10001488', '10001760', '10005169', '10010264', '10010305', '10015946', '10016322', '10020751', '10027374', '10033557', '10034336', '10040844', '10040954', '10041466', '10043118', '10047700', '10051602', '10054786', '10058920']
# ['10039906']
# ['10008479', '10013710', '10014392']
# ['10036590', '10051139', '10071404']
# ['10038435']
# ['10000087', '10028813']
# ['10035664']
# ['10003658']
# ['10076573']
# ['10046735']
# ['10012174', '10013573', '10064882']
# ['10011906', '10054112']
# ['10008111']
# ['10023676', '10070863']
# ['10015150', '10019974', '10037855', '10037876']
# ['10003246', '10048334', '10061194', '10074903']
# ['10071408']
# ['10016322']
# ['10013709', '10061818']
# ['10044223', '10072268']
# ['10069868']
# ['10023676', '10033661', '10070863']
# ['10013952', '10020751']
# ['10015150', '10028334', '10047895', '10048959', '10061364']
# ['10001760', '10013968', '10015150', '10015915', '10017577', '10030095', '10037087', '10037844', '10037844', '10038435', '10055798', '10061428']
# ['10005750']
# ['10063829', '10068945', '10069853', '10069880']
# ['10013573', '10016173', '10024855', '10039117', '10065016', '10073354']
# ['10020772', '10037660']
# ['10000060', '10008479', '10017885', '10061428', '10061549']
# ['10017577', '10021058', '10031250', '10033371', '10049471', '10055030', '10059866']
# ['10016256']
# ['10000059', '10000087', '10013952']
# ['10000059', '10003549', '10016322', '10025482', '10025482', '10028813', '10048828', '10060933']
# ['10047899']
# ['10003239', '10003246', '10006002', '10007697', '10028391']
# ['10019211']
# ['10023547']
# ['10035598']
# ['10020772', '10038435']
# ['10022052', '10022067', '10051572']
# ['10022061', '10022093', '10022112', '10023232']
# ['10002855', '10022116', '10033371', '10049119', '10053762', '10071408']
# ['10067499', '10073513']
# ['10013946']
# ['10067482']
# ['10053425']
# ['10002855', '10016256', '10028334']
# ['10033775']
# ['10018884']
# ['10005396', '10013911', '10028813', '10047700', '10062189']
# ['10005364', '10005483', '10024690']
# ['10022067', '10025482', '10047461']
# ['10027175', '10048592']
# ['10038428']
# ['10011224', '10037377', '10049414']
# ['10020751', '10037884']
# ['10022086', '10057362']
# ['10002855', '10006451', '10010356', '10014011', '10016173', '10017107', '10018823', '10020771', '10024929', '10029417', '10037213', '10045458', '10048586', '10061046', '10061070', '10061159', '10061265', '10062334', '10062339', '10062347', '10070976', '10071404', '10072889', '10073767']
# ['10012735']
# ['10017577']
# ['10003553', '10010774', '10019211', '10019211', '10019211', '10019211', '10019211', '10019211', '10019211', '10019211', '10025482', '10028810', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10028813', '10030095', '10037844', '10037844', '10061373', '10061428', '10061428']
# ['10003239', '10016322', '10017944']
# ['10000234', '10008190', '10027091', '10073513']
# ['10003239']
# ['10033557']
# ['10037087', '10037844', '10037867', '10040943']
# ['10028810']
# ['10021789', '10043607', '10058046', '10075192']
# ['10003658', '10003986', '10018964']
# ['10070863']
# ['10002034', '10003549', '10006825', '10008479', '10013971', '10016960', '10017577', '10031252', '10036057', '10049041', '10049187', '10053692']
# ['10013700']
# ['10011906']
# ['10013946', '10053762', '10076309']
# ['10022116']
# ['10002424']
# ['10076309']
# ['10005734', '10007515', '10058151']
# ['10033425', '10033775', '10052904']
# ['10049046']
# ['10011906']
# ['10014184']
# ['10020764']
# ['10001052', '10039020']
# ['10012735', '10016322', '10016952', '10017577', '10025482', '10028334', '10061520']
# ['10013573', '10042772', '10045555']
# ['10020937', '10024124', '10043607', '10061226']
# ['10037087', '10037844']
# ['10075192']
# ['10075192']
# ['10011906']
# ['10010214']
# ['10003757']
# ['10012578']
# ['10064684']
# ['10012575', '10069868']
# ['10013968', '10017413', '10028334', '10030124', '10035226']
# ['10011906']
# ['10013710', '10040741', '10075889']
# ['10069868']
# ['10022052', '10022061']
# ['10015958', '10016256', '10016825', '10019211', '10028836']
# ['10060891']
# ['10012378', '10013573', '10033307']
# ['10033295', '10043417', '10048779']
# ['10005746', '10013786', '10047895']
# ['10046306']
# ['10015946']
# ['10022061', '10022086', '10022095', '10022112']
# ['10051077']
# ['10047700']
# ['10011224']
# ['10003885', '10052066']
# ['10000060', '10000081', '10013082']
# ['10011906']
# ['10003988', '10028334', '10034754', '10037844', '10037884']
# ['10047942']
# ['10011906']
# ['10033474', '10040829', '10040952', '10060954', '10067868']
# ['10064355']
# ['10012607']
# ['10022116']
# ['10048886', '10064355']
# ['10002974']
# ['10048959']
# ['10064355']
# ['10012818', '10020117', '10051398', '10061819']
# ['10018932', '10020772', '10021328', '10043554', '10053762']
# ['10022095']
# ['10061623', '10062355']
# ['10047895']
# ['10025487', '10043414']
# ['10013036', '10016173', '10028813', '10039906', '10049848']
# ['10072878']
# ['10017955', '10028596']
# ['10011224', '10019211']
# ['10013573', '10019211', '10019303', '10024855', '10061024']
# ['10020642', '10060800']
# ['10067508', '10071404']
# ['10012378', '10019063', '10041308', '10042458']
# ['10003549', '10013573', '10016256', '10024264']
# ['10013710', '10013968']
# ['10044565']
# ['10003239']
# ['10005003', '10011906']
# ['10001760']
# ['10013781']
# ['10002882', '10008190', '10019465']
# ['10008479']
# ['10011906']
# ['10064385']
# ['10013952']
# ['10076309']
# ['10027339']
# ['10002855', '10013916', '10043431']
# ['10028810']
# ['10011906']
# ['10011906']
# ['10000081', '10003553', '10005591', '10005750', '10006482', '10008469', '10008479', '10008531', '10011224', '10013968', '10015967', '10016256', '10019211', '10020751', '10022437', '10025482', '10028735', '10033132', '10033371', '10036790', '10037087', '10039101', '10041232', '10041807', '10043224', '10047924', '10052438', '10061822', '10068319']
# ['10011906']

# %%
filtered_df = patient_safety_df[
    patient_safety_df['indications'].apply(lambda codes: any(code in breast_cancer_codes for code in codes))
]

# %%
filtered_df.to_csv('../fda_data/breast_cancer_patient_safety.csv')

# %%
import ast
from collections import Counter
import matplotlib.pyplot as plt
breast_safety_df = breast_cancer_df

def safe_parse(val):
    try:
        parsed = ast.literal_eval(val) if isinstance(val, str) else val
        return parsed if isinstance(parsed, list) else []
    except:
        return []

breast_safety_df.loc[:, 'SE'] = breast_safety_df['SE'].apply(safe_parse)

# Step 2: Flatten all MedDRA codes from the SE column
all_se_codes = [
    code for sublist in breast_safety_df['SE'] 
    if isinstance(sublist, list) 
    for code in sublist
]

# Step 3: Count occurrences
se_counter = Counter(all_se_codes)

# Step 4: Map MedDRA codes to LLTs
meddra_mapping_df['MedDRA Code'] = meddra_mapping_df['MedDRA Code'].astype(str)
llt_mapping = dict(zip(meddra_mapping_df['MedDRA Code'], meddra_mapping_df['MedDRA LLT']))

llt_counter = {}
for code, count in se_counter.items():
    term = llt_mapping.get(code, f"Unknown ({code})")
    llt_counter[term] = llt_counter.get(term, 0) + count

# Step 5: Plot top 10 LLTs
top_terms = dict(sorted(llt_counter.items(), key=lambda x: x[1], reverse=True)[:50])

plt.figure(figsize=(8, 8))
plt.pie(top_terms.values(), labels=top_terms.keys(), autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Adverse Events (Preferred Terms)')
plt.axis('equal')
plt.show()

# %%
filtered_df['SE'].to_list()
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
all_se_codes
# Out:
# []

# %%
patient_safety_df['drugs'].unique()
# Out:
# array(['[]', "['DB00005']", "['DB00399', 'DB00399', 'DB00399']", ...,
#        "['DB00264', 'DB00264', 'DB00264', 'DB00327', 'DB00641', 'DB00700', 'DB00700', 'DB01050', 'DB09292']",
#        "['DB00153', 'DB01373', 'DB05829', 'DB05829', 'DB05829']",
#        "['DB00169', 'DB00193', 'DB00343', 'DB00404', 'DB00480', 'DB00480', 'DB00480', 'DB00480', 'DB01076']"],
#       dtype=object)

# %%
patient_safety_df['indications'].unique()
# Out:
# array(['[]', "['10039073']", "['10058467', '10059515', '10059515']", ...,
#        "['10010428', '10010428', '10010428', '10037660']",
#        "['10002091', '10007649', '10007649', '10007649', '10029173', '10064736', '10070592']",
#        "['10012438', '10012438', '10012438', '10012438', '10012438', '10012438', '10012438', '10012438', '10012438', '10012438', '10077512', '10077512', '10077512']"],
#       dtype=object)

# %%
patient_safety_df['drugs']
# Out:
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
#                                ...
# 9325726                                     ['DB00182']
# 9325727                                     ['DB01050']
# 9325728                                     ['DB01281']
# 9325729                                     ['DB00497']
# 9325730    ['DB00295', 'DB00327', 'DB00497', 'DB00497']
# Name: drugs, Length: 9325731, dtype: object

# %%
ae_mapping_df = pd.read_csv('../fda_data/covid_study_preprocessed_data/AE_mapping.csv', sep='\t')

# %%
ae_mapping_df
# Out:
#              PT                          PT_name       HLT  \
# 0      10000002   11-beta-hydroxylase deficiency  10021608
# 1      10000005            17 ketosteroids urine  10038589
# 2      10000007  17 ketosteroids urine decreased  10038589
# 3      10000009  17 ketosteroids urine increased  10038589
# 4      10000011     17 ketosteroids urine normal  10038589
# ...         ...                              ...       ...
# 24308  10084459            asymptomatic covid-19  10084510
# 24309  10084460               covid-19 treatment  10002790
# 24310  10084461               sars-cov-2 carrier  10021910
# 24311  10084468                       quarantine  10027700
# 24312  10084480   sars-cov-2 test false negative  10047490
#
#                                  HLT_name      HLGT  \
# 0      inborn errors of steroid synthesis  10027424
# 1           reproductive hormone analyses  10014706
# 2           reproductive hormone analyses  10014706
# 3           reproductive hormone analyses  10014706
# 4           reproductive hormone analyses  10014706
# ...                                   ...       ...
# 24308              coronavirus infections  10047438
# 24309             antiinfective therapies  10043413
# 24310        infectious disorders carrier  10002252
# 24311          therapeutic procedures nec  10043413
# 24312   virus identification and serology  10027529
#
#                                             HLGT_name       SOC  \
# 0      metabolic and nutritional disorders congenital  10010331
# 1        endocrine investigations (incl sex hormones)  10022891
# 2        endocrine investigations (incl sex hormones)  10022891
# 3        endocrine investigations (incl sex hormones)  10022891
# 4        endocrine investigations (incl sex hormones)  10022891
# ...                                               ...       ...
# 24308                      viral infectious disorders  10021881
# 24309  therapeutic procedures and supportive care nec  10042613
# 24310                     ancillary infectious topics  10021881
# 24311  therapeutic procedures and supportive care nec  10042613
# 24312        microbiology and serology investigations  10022891
#
#                                          SOC_name SOC_abbr
# 0      congenital, familial and genetic disorders     Cong
# 1                                  investigations      Inv
# 2                                  investigations      Inv
# 3                                  investigations      Inv
# 4                                  investigations      Inv
# ...                                           ...      ...
# 24308                 infections and infestations    Infec
# 24309             surgical and medical procedures     Surg
# 24310                 infections and infestations    Infec
# 24311             surgical and medical procedures     Surg
# 24312                              investigations      Inv
#
# [24313 rows x 9 columns]

# %%
drug_atc_mapping_df = pd.read_csv('../fda_data/covid_study_preprocessed_data/drug_ATC_mapping.csv', sep='\t')

# %%
drug_atc_mapping_df.columns.to_list()
# Out:
# ['DBID',
#  'ATC_Subclass_1',
#  'ATC_ATC_Subclass_2',
#  'Subclass_4',
#  'ATC_Subclass_3',
#  'ATC_Class',
#  'string_name',
#  'FAERScode']

# %%
drug_atc_mapping_df.head()
# Out:
#       DBID                                   ATC_Subclass_1                                        ATC_ATC_Subclass_2                   Subclass_4                              ATC_Subclass_3                                   ATC_Class          string_name  FAERScode
# 0  DB00001                       Direct thrombin inhibitors                                     ANTITHROMBOTIC AGENTS        ANTITHROMBOTIC AGENTS              BLOOD AND BLOOD FORMING ORGANS              BLOOD AND BLOOD FORMING ORGANS            lepirudin        0.0
# 1  DB00002                            Monoclonal antibodies                               OTHER ANTINEOPLASTIC AGENTS        ANTINEOPLASTIC AGENTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS            cetuximab        1.0
# 2  DB00003                                       Mucolytics  EXPECTORANTS, EXCL. COMBINATIONS WITH COUGH SUPPRESSANTS  COUGH AND COLD PREPARATIONS                          RESPIRATORY SYSTEM                          RESPIRATORY SYSTEM         dornase alfa        2.0
# 3  DB00004                      Other antineoplastic agents                               OTHER ANTINEOPLASTIC AGENTS        ANTINEOPLASTIC AGENTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS  denileukin diftitox        3.0
# 4  DB00005  Tumor necrosis factor alpha (TNF-α) inhibitors                                        IMMUNOSUPPRESSANTS           IMMUNOSUPPRESSANTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS           etanercept        4.0

# %%
import pandas as pd

# Set display options
pd.set_option('display.max_rows', None)         # Show all rows
pd.set_option('display.max_colwidth', None)     # Show full column content
pd.set_option('display.expand_frame_repr', False)

# Now print the full list
print(drug_atc_mapping_df['string_name'].to_list())
# Out:
# ['lepirudin', 'cetuximab', 'dornase alfa', 'denileukin diftitox', 'etanercept', 'bivalirudin', 'leuprolide', 'leuprolide', 'peginterferon alfa-2a', 'peginterferon alfa-2a', 'alteplase', 'alteplase', 'sermorelin', 'sermorelin', 'interferon alfa-n1', 'darbepoetin alfa', 'urokinase', 'goserelin', 'reteplase', 'erythropoietin', nan, 'pegfilgrastim', 'sargramostim', 'peginterferon alfa-2b', 'peginterferon alfa-2b', nan, 'thyrotropin alfa', nan, 'anakinra', nan, nan, 'insulin human', 'insulin human', 'insulin human', 'insulin human', 'insulin human', 'tenecteplase', 'menotropins', nan, 'desmopressin', 'coagulation factor viia recombinant human', 'oprelvekin', 'palifermin', 'glucagon', 'aldesleukin', nan, 'omalizumab', 'lutropin alfa', 'insulin lispro', 'insulin lispro', 'insulin lispro', 'insulin glargine', 'insulin glargine', 'collagenase clostridium histolyticum', 'collagenase clostridium histolyticum', 'collagenase clostridium histolyticum', 'rasburicase', 'rasburicase', 'cetrorelix', 'adalimumab', nan, 'imiglucerase', 'abciximab', nan, 'gemtuzumab ozogamicin', nan, nan, 'pegaspargase', 'interferon beta-1a', 'pegademase', 'eptifibatide', 'infliximab', 'follitropin', 'follitropin', 'follitropin', 'interferon beta-1b', 'interferon alfacon-1', 'insulin pork', 'insulin pork', 'insulin pork', 'insulin pork', 'trastuzumab', 'rituximab', 'basiliximab', nan, nan, 'ibritumomab tiuxetan', 'daptomycin', 'tositumomab', 'pegvisomant', 'botulinum toxin type a', 'pancrelipase', 'streptokinase', 'streptokinase', 'alemtuzumab', 'alglucerase', nan, 'laronidase', 'cyclosporine', 'cyclosporine', 'alefacept', 'urofollitropin', 'efalizumab', 'choriogonadotropin alfa', nan, 'filgrastim', 'becaplermin', 'becaplermin', 'agalsidase beta', 'agalsidase beta', 'octreotide', 'interferon alfa-2b', 'abarelix', 'oxytocin', 'oxytocin', 'natalizumab', 'enfuvirtide', 'palivizumab', 'daclizumab', 'bevacizumab', nan, 'pyridoxal phosphate', 'cyanocobalamin', 'cyanocobalamin', 'cyanocobalamin', 'ademetionine', 'biotin', nan, 'arginine', 'ascorbic acid', 'ascorbic acid', 'ascorbic acid', 'ascorbic acid', 'ornithine', nan, 'methionine', 'calcitriol', 'calcitriol', 'riboflavin', 'riboflavin', 'glutamic acid', 'glutathione', 'glycine', 'calcifediol', 'tryptophan', 'thiamine', 'ergocalciferol', 'folic acid', 'folic acid', 'folic acid', 'folic acid', 'vitamin a', 'vitamin a', 'vitamin a', 'vitamin a', 'vitamin a', 'pyridoxine', 'pyridoxine', nan, 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'cholecalciferol', 'menadione', 'pravastatin', 'pravastatin', 'pravastatin', 'fluvoxamine', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'valsartan', 'ramipril', 'ramipril', 'ramipril', 'ramipril', 'ramipril', 'ramipril', 'ramipril', nan, 'flunisolide', 'flunisolide', 'baclofen', 'amphetamine', nan, 'nicotine', 'cevimeline', 'lorazepam', 'lorazepam', 'esmolol', 'bortezomib', nan, 'phentermine', 'tramadol', 'tramadol', 'tramadol', 'vidarabine', 'vidarabine', 'betaxolol', 'betaxolol', 'betaxolol', 'fluconazole', 'fluconazole', 'fluconazole', 'troglitazone', 'oseltamivir', 'erythromycin', 'erythromycin', 'erythromycin', 'erythromycin', 'hydroxocobalamin', 'hydroxocobalamin', 'hydroxocobalamin', 'caffeine', 'caffeine', 'caffeine', 'succinylcholine', 'sildenafil', 'sildenafil', 'dofetilide', 'pyrimethamine', 'pyrimethamine', 'pyrimethamine', 'reserpine', 'reserpine', 'reserpine', 'reserpine', 'reserpine', 'azithromycin', 'azithromycin', 'azithromycin', 'ticlopidine', 'trospium', 'trospium', 'adapalene', 'adapalene', 'midodrine', nan, 'pantoprazole', 'pantoprazole', 'pantoprazole', nan, nan, 'citalopram', 'eletriptan', 'bethanidine', 'moxifloxacin', 'moxifloxacin', nan, nan, 'nelfinavir', 'glimepiride', 'glimepiride', 'glimepiride', 'diflorasone', 'indinavir', 'gadodiamide', 'lovastatin', 'lovastatin', 'enflurane', 'cefotiam', 'pre ...

# %%
drug_atc_mapping_df['ATC_Subclass_1'].unique()
# Out:
# array(['Direct thrombin inhibitors', 'Monoclonal antibodies',
#        'Mucolytics', 'Other antineoplastic agents',
#        'Tumor necrosis factor alpha (TNF-α) inhibitors',
#        'Gonadotropin releasing hormone analogues', 'Interferons',
#        'Enzymes', 'Other ophthalmologicals',
#        'Tests for pituitary function',
#        'Somatropin and somatropin agonists',
#        'Other antianemic preparations', 'Calcitonin preparations',
#        'Colony stimulating factors', 'Thyrotropin',
#        'Blood coagulation factors', 'Interleukin inhibitors',
#        'Antibiotics',
#        'Insulins and analogues for injection, intermediate-acting',
#        'Insulins and analogues for injection, long-acting',
#        'Insulins and analogues for injection, fast-acting',
#        'Insulins and analogues for injection, intermediate- or long-acting combined with fast-acting',
#        'Insulins and analogues for inhalation', 'Gonadotropins',
#        'Vasopressin and analogues', 'Interleukins',
#        'Detoxifying agents for antineoplastic treatment',
#        'Glycogenolytic hormones',
#        'Other muscle relaxants, peripherally acting agents',
#        'Other systemic drugs for obstructive airway diseases',
#        'Proteolytic enzymes', 'Other antigout preparations',
#        'Anti-gonadotropin-releasing hormones',
#        'Platelet aggregation inhibitors excl. heparin',
#        'Indium (111In) compounds', 'Proteinase inhibitors',
#        'Other immunostimulants', 'Selective immunosuppressants',
#        'Antidotes', 'Various therapeutic radiopharmaceuticals',
#        'Other antibacterials', 'Iodine (131I) compounds',
#        'Other anterior pituitary lobe hormones and analogues',
#        'Enzyme preparations', 'Calcineurin inhibitors',
#        'Other cicatrizants', 'Other agents for local oral treatment',
#        'Somatostatin and analogues',
#        'Other hormone antagonists and related agents',
#        'Ergot alkaloids and oxytocin incl. analogues, in combination',
#        'Oxytocin and analogues', 'Other antivirals',
#        'Specific immunoglobulins', 'Technetium (99mTc) compounds',
#        'Other plain vitamin preparations',
#        'Vitamin B12 (cyanocobalamin and analogues)',
#        'Iron in other combinations', 'Amino acids and derivatives',
#        'Amino acids', 'Organic acids', 'Ascorbic acid (vitamin C), plain',
#        'Ascorbic acid (vitamin C), combinations', 'Liver therapy',
#        'Other antipsoriatics for topical use', 'Vitamin D and analogues',
#        'Acid preparations', 'Other irrigating solutions',
#        'Other antidepressants', 'Vitamin B1, plain',
#        'Folic acid and derivatives', 'Tests for fat absorption',
#        'Retinoids for topical use in acne', 'Other nasal preparations',
#        'Vitamin A, plain',
#        'Combinations of drugs for treatment of tuberculosis',
#        'Various alimentary tract and metabolism products',
#        'Bisphosphonates, combinations',
#        'Other drugs affecting bone structure and mineralization',
#        'Vitamin K', 'HMG CoA reductase inhibitors',
#        'HMG CoA reductase inhibitors in combination with other lipid modifying agents',
#        'HMG CoA reductase inhibitors, other combinations',
#        'Selective serotonin reuptake inhibitors',
#        'Angiotensin II receptor blockers (ARBs), other combinations',
#        'Angiotensin II receptor blockers (ARBs) and diuretics',
#        'Angiotensin II receptor blockers (ARBs), plain',
#        'Angiotensin II receptor blockers (ARBs) and calcium channel blockers',
#        'ACE inhibitors, other combinations',
#        'ACE inhibitors and calcium channel blockers',
#        'ACE inhibitors and diuretics', 'ACE inhibitors, plain',
#        'Corticosteroids', 'Glucocorticoids',
#        'Other centrally acting agents',
#        'Centrally acting sympathomimetics', 'Tests for gastric secretion',
#        'Drugs used in nicotine dependence', 'Other parasympathomimetics',
#        'Benzodiazepine derivatives', 'Beta blocking agents, selective',
#        'Other hypnotics and sedatives',
#        'Centrally acting antiobesity products',
#        'Opioids in combination with non-opioid analgesics',
#        'Other opioids',
#        'Nucleosides and nucleotides excl. reverse transcriptase inhibitors',
#        'Antivirals', 'Beta blocking agents',
#        'Combinations of antibacterials', 'Triazole derivatives',
#        'Imidazole and triazole derivatives', 'Thiazolidinediones',
#        'Neuraminidase inhibitors', 'Macrolides',
#        'Antiinfectives for treatment of acne', 'Xanthines',
#        'Xanthine derivatives', 'Choline derivatives', 'Sulfonamides',
#        'Drugs used in erectile dysfunction', 'Antiarrhythmics, class III',
#        'Diaminopyrimidines', 'Artemisinin and derivatives, combinations',
#        'Rauwolfia alkaloids and diuretics in combination',
#        'Rauwolfia alkaloids',
#        'Synthetic anticholinergic agents in combination with analgesics',
#        'Drugs for urinary frequency and incontinence',
#        'Adrenergic and dopaminergic agents', 'Renin-inhibitors',
#        'Combinations for eradication of Helicobacter pylori',
#        'Proton pump inhibitors', 'Sulfonamides, plain',
#        'Selective serotonin (5HT1) agonists', 'Guanidine derivatives',
#        'Fluoroquinolones',
#        'Synthetic anticholinergics, quaternary ammonium compounds',
#        'Protease inhibitors',
#        'Combinations of oral blood glucose lowering drugs',
#        'Sulfonylureas', 'Corticosteroids, potent (group III)',
#        'Paramagnetic contrast media', 'Halogenated hydrocarbons',
#        'Second-generation cephalosporins', 'Other antiepileptics',
#        'Thiazides, plain', 'Thiazides and potassium in combination',
#        'Aminosalicylic acid and derivatives',
#        'Phosphodiesterase inhibitors', 'Other alkylating agents',
#        'Barbiturates, combinations',
#        'Non-nucleoside reverse transcriptase inhibitors',
#        'Antivirals for treatment of HIV infections, combinations',
#        'Imidazole derivatives',
#        'Corticosteroids, moderately potent (group II)',
#        'Corticosteroids, plain', 'Purine analogues',
#        'Other cardiac preparations',
#        'Aminosalicylic acid and similar agents',
#        'Ethers of tropine or tropine derivatives', 'Indole derivatives',
#        'Ergot alkaloids', 'Dopamine agonists', 'Prolactine inhibitors',
#        'Other anti-acne preparations for topical use',
#        'Drugs for treatment of lepra', 'Hydantoin derivatives',
#        'Tetracyclines',
#        'Antiinfectives and antiseptics for local oral treatment',
#        'Estrogens', 'Estrogens, combinations with other drugs',
#        'Synthetic estrogens, plain',
#        'Drugs for treatment of hyperkalemia and hyperphosphatemia',
#        'Short-acting sulfonamides', 'Nitrosoureas',
#        'Beta blocking agents and calcium channel blockers',
#        'Beta blocking agents, other combinations',
#        'Beta blocking agents, selective, and thiazides',
#        'Beta blocking agents, selective, and other diuretics',
#        'Vitamin K antagonists', 'Third-generation cephalosporins',
#        'Natural and semisynthetic estrogens, plain',
#        'Dihydropyridine derivatives',
#        'Watersoluble, nephrotropic, high osmolar X-ray contrast media',
#        'Xanthines and adrenergics', 'Thyroid hormones',
#        'Antiarrhythmics, class Ia', 'Local anesthetics',
#        'Anesthetics for topical use', 'Anesthetics, local',
#        'Antiarrhythmics, class Ib', 'Analgesics and anesthetics',
#        'Amides', 'Bisphosphonates', 'Antihistamines for topical use',
#        'Aminoalkyl ethers', 'Alpha glucosidase inhibitors',
#        'Prostaglandin analogues', 'Other cytotoxic antibiotics',
#        'Nitrogen mustard analogues', 'Other general anesthetics',
#        'Folic acid analogues', 'Progestogens', 'Antipropulsives',
#        'Natural opium alkaloids',
#        'Opioids in combination with antispasmodics',
#        'Other antiglaucoma preparations',
#        'Nucleoside and nucleotide reverse transcriptase inhibitors',
#        'Combinations of penicillins, incl. beta-lactamase inhibitors',
#        'Beta-lactamase resistant penicillins', 'Carbapenems',
#        'Progestogens and estrogens, sequential preparations',
#        'Progestogens and estrogens, fixed combinations',
#        'Barbiturates, plain', 'Vinca alkaloids and analogues',
#        'Low-ceiling diuretics and potassium-sparing agents',
#        'Sulfonamides and potassium in combination',
#        'Fatty acid derivatives', 'Anilides', 'Protein kinase inhibitors',
#        'Opium alkaloids and derivatives',
#        'Penicillins with extended spectrum',
#        'Non-selective monoamine reuptake inhibitors',
#        'Antidepressants in combination with psycholeptics',
#        'Pyrimidine analogues', 'Other dopaminergic agents',
#        'Corticosteroids, moderately potent, other combinations',
#        'Corticosteroids and mydriatics in combination',
#        'Corticosteroids, moderately potent, combinations with antibiotics',
#        'Corticosteroids/antiinfectives/mydriatics in combination',
#        'Corticosteroids and antiinfectives in combination',
#        'Corticosteroids, combinations for treatment of acne',
#        'Nitroferricyanide derivatives', 'Calcium',
#        'Antiinflammatory agents, non-steroids and antiinfectives in combination',
#        'Acetic acid derivatives and related substances',
#        'Antiinflammatory agents, non-steroids',
#        'Antiinflammatory preparations, non-steroids for topical use',
#        'Other drugs for treatment of tuberculosis', 'Biguanides',
#        'Anticholinergics',
#        'Adrenergics in combination with anticholinergics incl. triple combinations with corticosteroids',
#        'Drugs used in opioid dependence',
#        'Diphenylpropylamine derivatives',
#        'Diazepines, oxazepines, thiazepines and oxepines',
#        'Beta blocking agents, selective, thiazides and other diuretics',
#        'Nitrofuran derivatives', 'Antiinfectives', 'Other antiinfectives',
#        'Medicated dressings with antiinfectives',
#        'Agents for dermatitis, excluding corticosteroids',
#        'Tertiary amines', 'Piperazine derivatives',
#        'Other antihistamines for systemic use',
#        'Benzothiazepine derivatives', 'Muscle relaxants',
#        'Tests for renal function and ureteral injuries',
#        'Alpha-adrenoreceptor antagonists', 'Oxazolidine derivatives',
#        'Other dermatologicals', 'Pyrimidine derivatives',
#        'Pregnadien derivatives', 'Monobactams',
#        'Oxazol, thiazine, and triazine derivatives',
#        'Aromatase inhibitors', 'Methanolquinolines',
#        'Combinations of sulfonamides and trimethoprim, incl. derivatives',
#        'Intermediate-acting sulfonamides',
#        'Other antimycotics for systemic use',
#        'Other drugs for peptic ulcer and gastro-oesophageal reflux disease (GORD)',
#        'Emergency contraceptives', 'Carbamates',
#        'Hypnotics and sedatives in combination, excl. barbiturates',
#        'Phenothiazine derivatives', 'Beta blocking agents, non-selective',
#        'Beta blocking agents, non-selective, and thiazides',
#        'Beta blocking agents, non-selective, thiazides and other diuretics',
#        'Bile acid sequestrants', 'Serotonin (5HT3) antagonists',
#        'Calcium channel blockers and diuretics', 'Anticholinesterases',
#        'Synthetic anticholinergics, esters with tertiary amino group',
#        'Synthetic anticholinergic agents in combination with psycholeptics',
#        'Other potassium-sparing agents',
#        'Anthracyclines and related substances',
#        'Sympathomimetics excl. antiglaucoma preparations',
#        'Sympathomimetics, combinations excl. corticosteroids',
#        'Sympathomimetics, plain', 'Sympathomimetics',
#        'Sympathomimetics used as decongestants',
#        'Sulfur-containing imidazole derivatives', 'Digitalis glycosides',
#        'Benzamides',
#        'Corticosteroids, potent, combinations with antibiotics',
#        'Adrenergics in combination with corticosteroids or other drugs, excl. anticholinergics',
#        'Corticosteroids acting locally', 'Carbamic acid esters',
#        'Pregnen (4) derivatives', 'Antifungals for systemic use',
#        'Benzodiazepine related drugs', 'Tests for bile duct patency',
#        'Substituted alkylamines', 'Other antiinfectives and antiseptics',
#        'Other antifungals for topical use',
#        'Other antibiotics for topical use', 'Choline esters',
#        'Parasympathomimetics', 'Beta-lactamase sensitive penicillins',
#        'Phenothiazines with aliphatic side-chain',
#        'Aldosterone antagonists', 'Belladonna alkaloids, tertiary amines',
#        'Belladonna and derivatives in combination with psycholeptics',
#        'Prostaglandins', 'Chlorine containing products',
#        'Phenothiazines with piperazine structure',
#        'Other respiratory system products',
#        'Preparations inhibiting uric acid production',
#        'Trimethoprim and derivatives',
#        'Corticosteroids, potent, combinations with antiseptics',
#        'Corticosteroids, potent, other combinations',
#        'Podophyllotoxin derivatives', 'Amphenicols',
#        'Sympathomimetics in glaucoma therapy',
#        'Butyrophenone derivatives', 'Phenylpiperidine derivatives',
#        'First-generation cephalosporins',
#        'Alpha-adrenoreceptor antagonists and diuretics',
#        'Retinoids for treatment of psoriasis',
#        'Antineovascularisation agents',
#        'Other antiinflammatory and antirheumatic agents, non-steroids',
#        'Barbiturates and derivatives',
#        'Sclerosing agents for local injection', 'Quinine and derivatives',
#        'Oxicams', 'Other antiemetics', 'Leukotriene receptor antagonists',
#        'Cyclic amines', 'Other aminoglycosides',
#        'Other immunosuppressants',
#        'Selective estrogen receptor modulators', 'Coxibs',
#        'Azaspirodecanedione derivatives', 'Anti-androgens',
#        'H2-receptor antagonists',
#        'Antivirals for treatment of HCV infections',
#        'Other agents against amoebiasis and other protozoal diseases',
#        'Other lipid modifying agents', 'Glycopeptide antibacterials',
#        'Other nervous system drugs', 'Platinum compounds',
#        'Benzimidazole derivatives', 'Tests for pancreatic function',
#        'Phosphonic acid derivatives', 'Anti-estrogens', 'Thiouracils',
#        'Other urologicals', 'Psoralens for systemic use',
#        'Psoralens for topical use', 'Diphenylmethane derivatives',
#        'Antihypertensives for pulmonary arterial hypertension',
#        'Respiratory stimulants', 'Carboxamide derivatives',
#        'Other quaternary ammonium compounds', 'Antivertigo preparations',
#        'Other antithrombotic agents', 'Propionic acid derivatives',
#        'Imidazoline receptor agonists in combination with diuretics',
#        'Imidazoline receptor agonists', 'Other antimigraine preparations',
#        'Osmotically acting laxatives', 'Piperazine and derivatives',
#        'Succinimide derivatives', 'Tetracycline and derivatives',
#        'Alpha and beta blocking agents and thiazides',
#        'Alpha and beta blocking agents and other diuretics',
#        'Alpha and beta blocking agents', 'Avermectines', 'Propulsives',
#        'Aminoquinolines', 'Thiocarbamide derivatives',
#        'Morphinan derivatives',
#        'Corticosteroids, moderately potent, combinations with antiseptics',
#        'Corticosteroids for local oral treatment',
#        'Androstan derivatives', '3-oxoandrosten (4) derivatives',
#        'Androgens and estrogens', 'Nicotinic acid and derivatives',
#        'Fibrates', 'Dipeptidyl peptidase 4 (DPP-4) inhibitors',
#        'Tests for fertility disturbances',
#        'Gonadotropin-releasing hormones', 'Other local anesthetics',
#        'Benzomorphan derivatives', 'Electrolyte solutions', 'Magnesium',
#        'Secondary and tertiary amines',
#        'Drugs used in alcohol dependence', 'Phenylalkylamine derivatives',
#        'Long-acting sulfonamides', 'Local hemostatics',
#        'Alpha- and beta-adrenoreceptor agonists',
#        'Other ectoparasiticides, incl. scabicides',
#        'Phenothiazines with piperidine structure',
#        'Other antiarrhythmics, class I and III',
#        'Heparins or heparinoids for topical use', 'Mineralocorticoids',
#        'Imidazoline derivatives', 'Colouring agents',
#        'Combinations of antineoplastic agents',
#        'High-ceiling diuretics and potassium-sparing agents',
#        'Carbonic anhydrase inhibitors',
#        'Sensitizers used in photodynamic/radiation therapy',
#        'Opioid anesthetics', 'Other throat preparations',
#        'Antiallergic agents, excl. corticosteroids',
#        'Other antiallergics', 'Estren derivatives',
#        'Esters of aminobenzoic acid', 'Organic nitrates',
#        'Other blood glucose lowering drugs, excl. insulins',
#        'Other antipsychotics',
#        'Other agents against leishmaniasis and trypanosomiasis',
#        'Corticosteroids, weak (group I)',
#        'Corticosteroids, weak, other combinations',
#        'Corticosteroids, weak, combinations with antiseptics',
#        'Corticosteroids, weak, combinations with antibiotics',
#        'Solutions producing osmotic diuresis', 'Iron chelating agents',
#        'Monoamine oxidase inhibitors, non-selective',
#        'Phenol and derivatives', 'Potassium',
#        'Tyrosine hydroxylase inhibitors',
#        'Thiazides, combinations with psycholeptics and/or analgesics',
#        'Other quinolones', 'Antiandrogens and estrogens',
#        'Intravaginal contraceptives', 'Fenamates',
#        'Antiinflammatory products for vaginal administration',
#        'Substituted ethylene diamines',
#        'Other topical products for joint and muscular pain', 'Polymyxins',
#        'Purine derivatives',
#        'Antiinflammatory/antirheumatic agents in combination with corticosteroids',
#        'Butylpyrazolidines', 'Non-selective beta-adrenoreceptor agonists',
#        'Sulfur containing products', 'Progesterone receptor modulators',
#        'Imidazothiazole derivatives', 'Penicillamine and similar agents',
#        'Salicylic acid and derivatives',
#        'Sympathomimetics, labour repressants', 'Other cough suppressants',
#        'Selective beta-2-adrenoreceptor agonists',
#        'Vasopressin antagonists', 'Expectorants',
#        'Thioxanthene derivatives', 'Antiseptics',
#        'Biguanides and amidines', 'Ovulation stimulants, synthetic',
#        'Nerve depressants', 'Other antiseptics and disinfectants',
#        'Aryloxyacetic acid derivatives', 'Esters of benzoic acid',
#        'Other anti-parathyroid agents', 'Nitroimidazole derivatives',
#        'Adamantane derivatives', 'Other chemotherapeutics',
#        'Oripavine derivatives', 'Other cardiac stimulants',
#        'Other peripheral vasodilators', 'Hydrazides',
#        'Corticosteroids for systemic use, combinations',
#        'Beta blocking agents, non-selective, and other diuretics',
#        'Serotonin receptor antagonists', 'Actinomycines',
#        'Melatonin receptor agonists', 'Retinoids for treatment of acne',
#        'Gold preparations', 'Thiazides, combinations with other drugs',
#        'Alkyl sulfonates', 'Other analgesics and antipyretics',
#        'Preparations increasing uric acid excretion',
#        'Monoamine oxidase B inhibitors', 'Other anti-dementia drugs',
#        'Other drugs for constipation',
#        'Quinoline derivatives and related substances',
#        'Other non-selective calcium channel blockers', 'Streptomycins',
#        'Peripherally acting antiobesity products',
#        'Strophanthus glycosides', 'Diphenylbutylpiperidine derivatives',
#        'Piperidinedione derivatives', 'Anticorticosteroids',
#        'Heparin group', 'Papaverine and derivatives',
#        'Sulfonium derivatives', 'Thiazide derivatives',
#        'Drugs for treatment of hypoglycemia', 'Tests for diabetes',
#        'Testosterone-5-alpha reductase inhibitors', 'Other antipruritics',
#        'Acidifiers', 'Methylhydrazines',
#        'Guanidine derivatives and diuretics',
#        'Monoamine oxidase A inhibitors',
#        'Ethers, chemically close to antihistamines',
#        'Ethers chemically close to antihistamines',
#        'Antiarrhythmics, class Ic',
#        'Peripheral opioid receptor antagonists',
#        'Non-watersoluble X-ray contrast media', 'Lincosamides',
#        'Curare alkaloids', 'Other antimalarials',
#        'Dantrolene and derivatives', 'Taxanes',
#        'Dopa and dopa derivatives',
#        'Watersoluble, nephrotropic, low osmolar X-ray contrast media',
#        'Hydrazinophthalazine derivatives',
#        'Hydrazinophthalazine derivatives and diuretics',
#        'Glucagon-like peptide-1 (GLP-1) analogues', 'ACTH',
#        'Multivitamins with minerals', 'Magnesium compounds',
#        'Sulfonamides (heterocyclic)',
#        'Other selective calcium channel blockers with mainly vascular effects',
#        'Salt solutions',
#        'Preparations with no effect on uric acid metabolism',
#        'Antigonadotropins and similar agents',
#        'Fourth-generation cephalosporins', 'Pyrazolones',
#        'Aldehydes and derivatives', 'Other intestinal adsorbents',
#        'Bile acids and derivatives',
#        'Other agents for treatment of hemorrhoids and anal fissures for topical use',
#        'Beta-lactamase inhibitors',
#        'Other drugs for functional gastrointestinal disorders',
#        'MAO inhibitors and diuretics', 'MAO inhibitors', 'Enemas',
#        'Bioflavonoids',
#        'Other sex hormones and modulators of the genital system',
#        'Quaternary ammonium compounds', 'Medicated shampoos',
#        'Protectives against UV-radiation for topical use',
#        'Aldose reductase inhibitors', 'Steroid antibacterials',
#        '5-androstanon (3) derivatives', 'Other i.v. solution additives',
#        'Solutions affecting the electrolyte balance',
#        'Carbamide products', 'Carbohydrates', 'Quinoline derivatives',
#        'Mercurial products', 'Ethylene imines',
#        'Other psychostimulants and nootropics',
#        'Watersoluble, hepatotropic X-ray contrast media',
#        'Preparations containing sulfur', 'Other antitrematodal agents',
#        'Hydroxyquinoline derivatives', 'Contact laxatives',
#        'Other vasodilators used in cardiac diseases',
#        'Antiandrogens, plain', 'Other gynecologicals',
#        'Pyrethrines, incl. synthetic compounds',
#        'Protectives against UV-radiation for systemic use',
#        'Other antidiarrheals',
#        'Other drugs for disorders of the musculo-skeletal system',
#        'Other plant alkaloids and natural products',
#        'Various pain palliation radiopharmaceuticals',
#        'Drugs used in hereditary angioedema',
#        'Other systemic hemostatics', 'Iodine products',
#        'Antimony compounds',
#        'Other magnetic resonance imaging contrast media',
#        'Parathyroid hormones and analogues',
#        '2-amino-1-phenylethanol derivatives', 'Other antiobesity drugs',
#        'Direct factor Xa inhibitors',
#        'Sodium-glucose co-transporter 2 (SGLT2) inhibitors',
#        'Other cephalosporins and penems',
#        'Artemisinin and derivatives, plain',
#        'Other diagnostic radiopharmaceuticals for tumour detection',
#        'Androgens and female sex hormones in combination with other drugs',
#        'Aluminium compounds',
#        'Combinations and complexes of aluminium, calcium and magnesium compounds',
#        'Calcium compounds', 'Other antihypertensives and diuretics',
#        'Capsaicin and similar agents',
#        'Drugs for treatment of hypercalcemia',
#        'Corticosteroids, very potent (group IV)',
#        'Salicylic acid derivatives', 'Other antinematodals',
#        'Other drugs for bile therapy', 'Other antithyroid preparations',
#        'Dichloroacetamide derivatives', 'Viscoelastic substances',
#        'Iodine (123I) compounds',
#        'Preparations for biliary tract therapy', 'Arsenic compounds',
#        'Antacids with antiflatulents',
#        'Belladonna alkaloids, semisynthetic, quaternary ammonium compounds',
#        'Other drugs for obstructive airway diseases, inhalants',
#        'Other anxiolytics', 'Dibenzo-bicyclo-octadiene derivatives',
#        'Other therapeutic products', 'Other estrogens', 'Peroxides',
#        'Blood substitutes and plasma protein fractions',
#        'Lung surfactants', 'Medical gases',
#        'Iron trivalent, oral preparations',
#        'Other central nervous system diagnostic radiopharmaceuticals',
#        'Sodium', 'Fibrinogen', 'Charcoal preparations',
#        'Various thyroid diagnostic radiopharmaceuticals',
#        'Belladonna and derivatives in combination with analgesics',
#        'Other respiratory system diagnostic radiopharmaceuticals', 'Zinc',
#        'Caries prophylactic agents', 'Fluoride', 'Mercurial diuretics',
#        'Other surgical aids',
#        'Other renal system diagnostic radiopharmaceuticals',
#        'Solutions for parenteral nutrition',
#        'Technetium (99mTc), particles and colloids', 'Perchlorates',
#        'Tests for thyreoidea function',
#        'Superparamagnetic contrast media', 'Immune sera',
#        'Rota virus diarrhea vaccines', 'Rubella vaccines',
#        'Allergen extracts', 'Bulk-forming laxatives', 'Tetanus vaccines',
#        'Diphtheria vaccines', 'Yellow fever vaccines',
#        'Softeners, emollients', 'Selenium', 'Silver compounds',
#        'Ultrasound contrast media',
#        'Barium sulfate containing X-ray contrast media',
#        'Tetrahydropyrimidine derivatives', 'Antracen derivatives',
#        'Other insecticides and repellents', 'Other anticestodals',
#        'Organophosphorous compounds', 'Acridine derivatives',
#        'Bone morphogenetic proteins',
#        'Tests for liver functional capacity',
#        'Corticosteroids, very potent, combinations with antibiotics',
#        'Serotonin antagonists', 'Other low-ceiling diuretics',
#        'Yttrium (90Y) compounds',
#        'Synthetic antispasmodics, amides with tertiary amines',
#        'Other capillary stabilizing agents',
#        'Enzyme and acid preparations, combinations',
#        'Iron bivalent, oral preparations', 'Quinolone vasodilators',
#        'Barbiturates in combination with other drugs',
#        'Other intestinal antiinfectives', 'Scilla glycosides',
#        'Colchicine derivatives', 'Epoxides', 'Other hem products',
#        'Other antiinflammatory therapeutic radiopharmaceuticals',
#        'Other sclerosing agents', 'Other immunoglobulins',
#        'Various diagnostic radiopharmaceuticals',
#        'Androgens for topical use', 'Quinolines', 'Ethers', 'Pyrethrines',
#        'Corticosteroid derivatives',
#        'Other drugs used in benign prostatic hypertrophy',
#        'Thiosemicarbazones', 'Streptogramins', 'Other cardiac glycosides',
#        'Pyrazolone derivatives', 'Iron in combination with folic acid'],
#       dtype=object)

# %%
drug_mapping_df = pd.read_csv('../fda_data/drug_mapping.csv', sep='\t')

# %%
drug_mapping_df
# Out:
#                 Drug  DrugBank ID
# 0          etanercept     DB00005
# 1     zoledronic acid     DB00399
# 2        atorvastatin     DB01076
# 3           metformin     DB00331
# 4       rosiglitazone     DB00412
# ...               ...         ...
# 3619   methylatropine     DB13833
# 3620      fosfructose     DB13863
# 3621    gluconic acid     DB13180
# 3622      pentolinium     DB01090
# 3623        gallamine     DB13584
#
# [3624 rows x 2 columns]
